# %% [markdown]
# ## Global Power Plant Database

# %% [markdown]
# ### 1.Data analysis

# %% [markdown]
#  (i) Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# (2) Data loading and cleaning

# %%
data= pd.read_csv('https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')

# %%
data.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
data.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# min        NaN                 2019.0                  NaN
# 25%        NaN                 2019.0                  NaN
# 50%        NaN                 2019.0                  NaN
# 75%        NaN                 2019.0                  NaN
# max        NaN                 2019.0                  NaN
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           398.000000           422.000000           434.000000
# mean           2431.823590          2428.226946          2467.936859
# std            4026.440035          4194.596959          4162.884308
# min               0.000000             0.000000             0.000000
# 25%             223.557672           176.381063           188.285252
# 50%             801.123775           711.181225           737.205450
# 75%            3035.306250          3084.121250          3282.861313
# max           28127.000000         30539.000000         30015.000000
#
#        generation_gwh_2017  generation_gwh_2018  generation_gwh_2019  \
# count           440.000000           448.000000                  0.0
# mean           2547.759305          2600.804099                  NaN
# std            4196.991169          4314.880456                  NaN
# min               0.000000             0.000000                  NaN
# 25%             177.874930           193.378250                  NaN
# 50%             817.977250           751.644375                  NaN
# 75%            3275.690475          3143.535900                  NaN
# max           35116.000000         35136.000000                  NaN
#
#        estimated_generation_gwh
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
#  13  source                    907 non-null    object
#  14  url                       907 non-null    object
#  15  geolocation_source        888 non-null    object
#  16  wepp_id                   0 non-null      float64
#  17  year_of_capacity_data     519 non-null    float64
#  18  generation_gwh_2013       0 non-null      float64
#  19  generation_gwh_2014       398 non-null    float64
#  20  generation_gwh_2015       422 non-null    float64
#  21  generation_gwh_2016       434 non-null    float64
#  22  generation_gwh_2017       440 non-null    float64
#  23  generation_gwh_2018       448 non-null    float64
#  24  generation_gwh_2019       0 non-null      float64
#  25  generation_data_source    449 non-null    object
#  26  estimated_generation_gwh  0 non-null      float64
# dtypes: float64(15), object(12)
# memory usage: 191.4+ KB

# %%
data.shape
# Out:
# (907, 27)

# %%
for i in data.columns:
  print(data[i].value_counts())
  print("________________________________________")
# Out:
# IND    907
# Name: country, dtype: int64
# ________________________________________
# India    907
# Name: country_long, dtype: int64
# ________________________________________
# KODASALI                         1
# SBT SUGAR                        1
# RAJPURA TPP                      1
# DGEN MEGA CCCP                   1
# Nokha Daiya Solar Power Plant    1
#                                 ..
# TEHRI ST -1                      1
# PENCH                            1
# NEYVELI ST I                     1
# MAIHAR CEMENT PLANT              1
# Kosa Wind Farm                   1
# Name: name, Length: 907, dtype: int64
# ________________________________________
# IND0000488    1
# WRI1019937    1
# IND0000095    1
# IND0000230    1
# IND0000499    1
#              ..
# WRI1026211    1
# IND0000150    1
# WRI1026086    1
# WRI1026794    1
# WRI1026087    1
# Name: gppd_idnr, Length: 907, dtype: int64
# ________________________________________
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64
# ________________________________________
# 24.1917    3
# 19.0004    3
# 15.2615    2
# 13.2450    2
# 11.5336    2
#           ..
# 16.4994    1
# 9.0870     1
# 20.9099    1
# 17.2387    1
# 16.5973    1
# Name: latitude, Length: 836, dtype: int64
# ________________________________________
# 71.6917    4
# 72.8983    3
# 81.2875    3
# 75.8988    3
# 71.6918    3
#           ..
# 77.9576    1
# 91.8114    1
# 80.1264    1
# 76.1137    1
# 79.5748    1
# Name: longitude, Length: 827, dtype: int64
# ________________________________________
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64
# ________________________________________
# Oil             195
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64
# ________________________________________
# Oil    1
# Name: other_fuel2, dtype: int64
# ________________________________________
# Series([], Name: other_fuel3, dtype: int64)
# ________________________________________
# 2015.0    28
# 2013.0    25
# 2012.0    23
# 2016.0    19
# 2010.0    18
#           ..
# 1958.0     1
# 1949.0     1
# 1954.0     1
# 1956.0     1
# 1927.0     1
# Name: commissioning_year, Length: 73, dtype: int64
# ________________________________________
# Acc Acc ltd                             4
# Sterling Agro Industries ltd.           4
# Jk Cement ltd                           4
# Powerica Limited                        3
# Shri Ssk ltd                            3
#                                        ..
# Gupta Ltd gepl)                         1
# Lanco Solar Energy Private Limited      1
# Khaya Solar Projects Private Limited    1
# EMCO Limited                            1
# Mono Steel (India) Ltd                  1
# Name: owner, Length: 280, dtype: int64
# ________________________________________
# Central Electricity Authority                519
# CDM                                          124
# Lancosola                                     10
# National Renewable Energy Laboratory           8
# National Thermal Power Corporation (NTPC)      6
#                                             ...
# SEI Solar Energy Private Limited               1
# Godavari Mills ltd                             1
# Mangalore & petrochem                          1
# Technocraft Technocraft group                  1
# Gupta Ltd gepl)                                1
# Name: source, Length: 191, dtype: int64
# ________________________________________
# http://www.cea.nic.in/                                                                                                                                                         519
# http://www.lancosolar.com/pdfs/rajasthan-pv-project-details.pdf                                                                                                                  7
# http://www.ntpc.co.in                                                                                                                                                            6
# http://viainfotech.biz/Biomass/theme5/document/green_market/REC-project-list.pdf                                                                                                 5
# http://www.azurepower.com                                                                                                                                                        4
#                                                                                                                                                                               ...
# https://cdm.unfccc.int/Projects/DB/RWTUV1342443620.03/view                                                                                                                       1
# https://cdm.unfccc.int/filestorage/i/o/Z9N7VXYJ5LIE8WRQM1SB3H4FDA6U2K.pdf/PDD%20with%20revised%20MP%20(ver%2010.0)(Clean%20mode).pdf?t=Qmt8b2picnBrfDBPz_lFTjdrigpAyplKqoQb      1
# https://cdm.unfccc.int/Projects/DB/BVQI1336676184.92/view                                                                                                                        1
# https://www.kesocorp.com/                                                                                                                                                        1
# https://cdm.unfccc.int/Projects/DB/BVQI1331114727.08/view                                                                                                                        1
# Name: url, Length: 304, dtype: int64
# ________________________________________
# WRI                                     765
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64
# ________________________________________
# Series([], Name: wepp_id, dtype: int64)
# ________________________________________
# 2019.0    519
# Name: year_of_capacity_data, dtype: int64
# ________________________________________
# Series([], Name: generation_gwh_2013, dtype: int64)
# ________________________________________
# 0.00000       28
# 6803.31250     1
# 4735.13000     1
# 145.81400      1
# 2022.57000     1
#               ..
# 6224.00000     1
# 268.48085      1
# 1255.73200     1
# 164.32425      1
# 1153.65300     1
# Name: generation_gwh_2014, Length: 371, dtype: int64
# ________________________________________
# 0.00000       27
# 174.17475      1
# 8076.81050     1
# 1.09395        1
# 18.71595       1
#               ..
# 665.19730      1
# 1516.36010     1
# 741.86205      1
# 183.29890      1
# 7130.50700     1
# Name: generation_gwh_2015, Length: 396, dtype: int64
# ________________________________________
# 0.00000       30
# 8470.57000     2
# 1511.00000     2
# 250.97100      1
# 7.31325        1
#               ..
# 433.84800      1
# 283.74811      1
# 259.94375      1
# 403.96000      1
# 307.87290      1
# Name: generation_gwh_2016, Length: 403, dtype: int64
# ________________________________________
# 0.00000       32
# 170.08530      2
# 9271.00000     1
# 59.43135       1
# 549.86930      1
#               ..
# 214.48220      1
# 272.73945      1
# 2887.00000     1
# 12.73600       1
# 158.73235      1
# Name: generation_gwh_2017, Length: 408, dtype: int64
# ________________________________________
# 0.00000       39
# 100.85320      1
# 805.48235      1
# 7179.00000     1
# 6915.39000     1
#               ..
# 980.25410      1
# 33.88970       1
# 6474.61425     1
# 347.34455      1
# 192.01510      1
# Name: generation_gwh_2018, Length: 410, dtype: int64
# ________________________________________
# Series([], Name: generation_gwh_2019, dtype: int64)
# ________________________________________
# Central Electricity Authority    449
# Name: generation_data_source, dtype: int64
# ________________________________________
# Series([], Name: estimated_generation_gwh, dtype: int64)
# ________________________________________

# %%
print(data.isnull().sum())
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
# drop or delete the column
data = data.drop(columns=['wepp_id','other_fuel3','other_fuel2','estimated_generation_gwh'], axis=1)

# %%
data['total_generation'] = data['generation_gwh_2014'] + data['generation_gwh_2015'] + data['generation_gwh_2016'] + data['generation_gwh_2017']+data['generation_gwh_2018']

# %%
data = data.drop(['generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018','generation_gwh_2019'],axis = 1)

# %%
data
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                   NaN                 Ultratech Cement ltd
# 2                   NaN                                  AES
# 3                2004.0                                  NaN
# 4                2015.0                                  NaN
# ..                  ...                                  ...
# 902              2016.0                                  NaN
# 903                 NaN  Karnataka Power Corporation Limited
# 904                 NaN                                  NaN
# 905                 NaN                   Hindustan Zinc ltd
# 906                 NaN                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory                    NaN
# 1                                     WRI                    NaN
# 2                                     WRI                    NaN
# 3                                     WRI                 2019.0
# 4                                     WRI                 2019.0
# ..                                    ...                    ...
# 902                                   WRI                 2019.0
# 903                        Industry About                    NaN
# 904                                   WRI                    NaN
# 905                                   WRI                    NaN
# 906                                   WRI                    NaN
#
#             generation_data_source  total_generation
# 0                              NaN               NaN
# 1                              NaN               NaN
# 2                              NaN               NaN
# 3    Central Electricity Authority       3637.554320
# 4    Central Electricity Authority      27859.499736
# ..                             ...               ...
# 902  Central Electricity Authority               NaN
# 903                            NaN               NaN
# 904                            NaN               NaN
# 905                            NaN               NaN
# 906                            NaN               NaN
#
# [907 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_data_source', 'total_generation'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 907 non-null    object
#  1   country_long            907 non-null    object
#  2   name                    907 non-null    object
#  3   gppd_idnr               907 non-null    object
#  4   capacity_mw             907 non-null    float64
#  5   latitude                861 non-null    float64
#  6   longitude               861 non-null    float64
#  7   primary_fuel            907 non-null    object
#  8   other_fuel1             198 non-null    object
#  9   commissioning_year      527 non-null    float64
#  10  owner                   342 non-null    object
#  11  source                  907 non-null    object
#  12  url                     907 non-null    object
#  13  geolocation_source      888 non-null    object
#  14  year_of_capacity_data   519 non-null    float64
#  15  generation_data_source  449 non-null    object
#  16  total_generation        391 non-null    float64
# dtypes: float64(6), object(11)
# memory usage: 120.6+ KB

# %%
print(data.isnull().sum())
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_data_source    458
# total_generation          516
# dtype: int64

# %% [markdown]
# Replacing missing values with mode

# %%
data['longitude'].fillna(data['longitude'].mode()[0], inplace=True)
data['latitude'].fillna(data['latitude'].mode()[0], inplace=True)
data['geolocation_source'].fillna(data['geolocation_source'].mode()[0], inplace=True)
data['other_fuel1'].fillna(data['other_fuel1'].mode()[0], inplace=True)
data['commissioning_year'].fillna(data['commissioning_year'].mode()[0], inplace=True)
data['owner'].fillna(data['owner'].mode()[0], inplace=True)
data['year_of_capacity_data'].fillna(data['year_of_capacity_data'].mode()[0], inplace=True)
data['generation_data_source'].fillna(data['generation_data_source'].mode()[0], inplace=True)
data['total_generation'].fillna(data['total_generation'].mode()[0], inplace=True)

# %%
print(data.isnull().sum())
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_data_source    0
# total_generation          0
# dtype: int64

# %%
data
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         Oil
# 1           98.0   24.7663    74.6090         Coal         Oil
# 2           39.2   21.9038    69.3732         Wind         Oil
# 3          135.0   23.8712    91.3602          Gas         Oil
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         Oil
# 904         25.5   15.2758    75.5811         Wind         Oil
# 905         80.0   24.3500    73.7477         Coal         Oil
# 906         16.5    9.9344    77.4768         Wind         Oil
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                2015.0                 Ultratech Cement ltd
# 2                2015.0                                  AES
# 3                2004.0                          Acc Acc ltd
# 4                2015.0                          Acc Acc ltd
# ..                  ...                                  ...
# 902              2016.0                          Acc Acc ltd
# 903              2015.0  Karnataka Power Corporation Limited
# 904              2015.0                          Acc Acc ltd
# 905              2015.0                   Hindustan Zinc ltd
# 906              2015.0                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory                 2019.0
# 1                                     WRI                 2019.0
# 2                                     WRI                 2019.0
# 3                                     WRI                 2019.0
# 4                                     WRI                 2019.0
# ..                                    ...                    ...
# 902                                   WRI                 2019.0
# 903                        Industry About                 2019.0
# 904                                   WRI                 2019.0
# 905                                   WRI                 2019.0
# 906                                   WRI                 2019.0
#
#             generation_data_source  total_generation
# 0    Central Electricity Authority          0.000000
# 1    Central Electricity Authority          0.000000
# 2    Central Electricity Authority          0.000000
# 3    Central Electricity Authority       3637.554320
# 4    Central Electricity Authority      27859.499736
# ..                             ...               ...
# 902  Central Electricity Authority          0.000000
# 903  Central Electricity Authority          0.000000
# 904  Central Electricity Authority          0.000000
# 905  Central Electricity Authority          0.000000
# 906  Central Electricity Authority          0.000000
#
# [907 rows x 17 columns]

# %%
for i in data.columns:
  print(data[i].value_counts())
  print("________________________________________")
# Out:
# IND    907
# Name: country, dtype: int64
# ________________________________________
# India    907
# Name: country_long, dtype: int64
# ________________________________________
# KODASALI                         1
# SBT SUGAR                        1
# RAJPURA TPP                      1
# DGEN MEGA CCCP                   1
# Nokha Daiya Solar Power Plant    1
#                                 ..
# TEHRI ST -1                      1
# PENCH                            1
# NEYVELI ST I                     1
# MAIHAR CEMENT PLANT              1
# Kosa Wind Farm                   1
# Name: name, Length: 907, dtype: int64
# ________________________________________
# IND0000488    1
# WRI1019937    1
# IND0000095    1
# IND0000230    1
# IND0000499    1
#              ..
# WRI1026211    1
# IND0000150    1
# WRI1026086    1
# WRI1026794    1
# WRI1026087    1
# Name: gppd_idnr, Length: 907, dtype: int64
# ________________________________________
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64
# ________________________________________
# 19.0004    49
# 24.1917     3
# 15.2615     2
# 13.2450     2
# 11.5336     2
#            ..
# 16.4994     1
# 9.0870      1
# 20.9099     1
# 17.2387     1
# 16.5973     1
# Name: latitude, Length: 836, dtype: int64
# ________________________________________
# 71.6917    50
# 72.8983     3
# 81.2875     3
# 75.8988     3
# 71.6918     3
#            ..
# 77.9576     1
# 91.8114     1
# 80.1264     1
# 76.1137     1
# 79.5748     1
# Name: longitude, Length: 827, dtype: int64
# ________________________________________
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64
# ________________________________________
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64
# ________________________________________
# 2015.0    408
# 2013.0     25
# 2012.0     23
# 2016.0     19
# 2010.0     18
#          ...
# 1958.0      1
# 1949.0      1
# 1954.0      1
# 1956.0      1
# 1927.0      1
# Name: commissioning_year, Length: 73, dtype: int64
# ________________________________________
# Acc Acc ltd                             569
# Sterling Agro Industries ltd.             4
# Jk Cement ltd                             4
# Powerica Limited                          3
# Shri Ssk ltd                              3
#                                        ...
# Gupta Ltd gepl)                           1
# Lanco Solar Energy Private Limited        1
# Khaya Solar Projects Private Limited      1
# EMCO Limited                              1
# Mono Steel (India) Ltd                    1
# Name: owner, Length: 280, dtype: int64
# ________________________________________
# Central Electricity Authority                519
# CDM                                          124
# Lancosola                                     10
# National Renewable Energy Laboratory           8
# National Thermal Power Corporation (NTPC)      6
#                                             ...
# SEI Solar Energy Private Limited               1
# Godavari Mills ltd                             1
# Mangalore & petrochem                          1
# Technocraft Technocraft group                  1
# Gupta Ltd gepl)                                1
# Name: source, Length: 191, dtype: int64
# ________________________________________
# http://www.cea.nic.in/                                                                                                                                                         519
# http://www.lancosolar.com/pdfs/rajasthan-pv-project-details.pdf                                                                                                                  7
# http://www.ntpc.co.in                                                                                                                                                            6
# http://viainfotech.biz/Biomass/theme5/document/green_market/REC-project-list.pdf                                                                                                 5
# http://www.azurepower.com                                                                                                                                                        4
#                                                                                                                                                                               ...
# https://cdm.unfccc.int/Projects/DB/RWTUV1342443620.03/view                                                                                                                       1
# https://cdm.unfccc.int/filestorage/i/o/Z9N7VXYJ5LIE8WRQM1SB3H4FDA6U2K.pdf/PDD%20with%20revised%20MP%20(ver%2010.0)(Clean%20mode).pdf?t=Qmt8b2picnBrfDBPz_lFTjdrigpAyplKqoQb      1
# https://cdm.unfccc.int/Projects/DB/BVQI1336676184.92/view                                                                                                                        1
# https://www.kesocorp.com/                                                                                                                                                        1
# https://cdm.unfccc.int/Projects/DB/BVQI1331114727.08/view                                                                                                                        1
# Name: url, Length: 304, dtype: int64
# ________________________________________
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64
# ________________________________________
# 2019.0    907
# Name: year_of_capacity_data, dtype: int64
# ________________________________________
# Central Electricity Authority    907
# Name: generation_data_source, dtype: int64
# ________________________________________
# 0.000000        527
# 15907.482900      1
# 1933.533750       1
# 4069.403000       1
# 18647.300000      1
#                ...
# 15429.695000      1
# 17319.354000      1
# 38894.480572      1
# 88252.000000      1
# 5789.715950       1
# Name: total_generation, Length: 381, dtype: int64
# ________________________________________

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_data_source', 'total_generation'],
#       dtype='object')

# %%
sns.countplot(x='primary_fuel',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %%
print(data['country'].value_counts())
print(data['country_long'].value_counts())
# Out:
# IND    907
# Name: country, dtype: int64
# India    907
# Name: country_long, dtype: int64

# %% [markdown]
# SINCE THERE IS ONLY VALUE IN TYPE REMOVING THAT COLUMN

# %% [markdown]
# #data=data.drop('country',axis=1)
# #data=data.drop('country_long',axis=1)

# %%
sns.countplot(x='other_fuel1',data=data)
# Out:
# <AxesSubplot:xlabel='other_fuel1', ylabel='count'>

# %% [markdown]
# SINCE THERE IS ONLY VALUE IN TYPE REMOVING THAT COLUMN

# %%
data=data.drop('other_fuel1',axis=1)

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='geolocation_source',hue='primary_fuel',data=data)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='count'>

# %%
print(data['year_of_capacity_data'].value_counts())
print(data['generation_data_source'].value_counts())
# Out:
# 2019.0    907
# Name: year_of_capacity_data, dtype: int64
# Central Electricity Authority    907
# Name: generation_data_source, dtype: int64

# %% [markdown]
# SINCE THERE IS ONLY VALUE IN TYPE REMOVING THAT COLUMN

# %%
sns.distplot(data['commissioning_year'], bins=20)
plt.title('commissioning_year')
plt.xlabel('commissioning_year')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
# Out:
# (array([1900., 1920., 1940., 1960., 1980., 2000., 2020., 2040.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.distplot(data['total_generation'], bins=20)
plt.title('total_generation')
plt.xlabel('total_generation')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
# Out:
# (array([-25000.,      0.,  25000.,  50000.,  75000., 100000., 125000.,
#         150000., 175000., 200000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.distplot(data['capacity_mw'], bins=20)
plt.title('capacity_mw')
plt.xlabel('capacity_mw')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.distplot(data['longitude'], bins=20)
plt.title('generation_data_source')
plt.xlabel('generation_data_source')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
# Out:
# (array([ 60.,  65.,  70.,  75.,  80.,  85.,  90.,  95., 100., 105.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.distplot(data['latitude'], bins=20)
plt.title('latitude')
plt.xlabel('latitude')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
ax = sns.scatterplot(x="commissioning_year", y="capacity_mw", data=data)

# %%
ax = sns.scatterplot(x="total_generation", y="capacity_mw", data=data)

# %% [markdown]
# the total_generation and capacity_mw are linearly increase

# %%
sns.pairplot(data,palette= "coolwarm")

# %% [markdown]
# # 3. Data pre-processing

# %% [markdown]
# ### Drop unnecessary columns
# We should drop the attributes year_of_capacity_data,generation_data_source,gppd_idnr,country and country_long because they all carry the same value for each row

# %%
#Delect the columns
data= data.drop(['country','country_long','year_of_capacity_data','generation_data_source'],axis=1)

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['name','primary_fuel','owner', 'source','geolocation_source','url','gppd_idnr']
le = LabelEncoder()

for col in cols:
    data[col] = le.fit_transform(data[col])
data.head()
# Out:
#    name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0     0        657          2.5   28.1839    73.2407             6
# 1     1        519         98.0   24.7663    74.6090             1
# 2     2        853         39.2   21.9038    69.3732             7
# 3     3          0        135.0   23.8712    91.3602             2
# 4     4          1       1800.0   21.9603    82.4091             1
#
#    commissioning_year  owner  source  url  geolocation_source  \
# 0              2011.0    229     109  128                   1
# 1              2015.0    258     174  173                   2
# 2              2015.0      2      21  205                   2
# 3              2004.0      5      22   58                   2
# 4              2015.0      5      22   58                   2
#
#    total_generation
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3       3637.554320
# 4      27859.499736

# %% [markdown]
# ### correlation

# %%
data.corr()
# Out:
#                         name  gppd_idnr  capacity_mw  latitude  longitude  \
# name                1.000000   0.332205     0.060240 -0.137256   0.011780
# gppd_idnr           0.332205   1.000000    -0.335742 -0.107710  -0.372802
# capacity_mw         0.060240  -0.335742     1.000000  0.059041   0.215875
# latitude           -0.137256  -0.107710     0.059041  1.000000   0.055202
# longitude           0.011780  -0.372802     0.215875  0.055202   1.000000
# primary_fuel        0.040753   0.609180    -0.380395 -0.020203  -0.368766
# commissioning_year -0.041465   0.511350    -0.004072  0.035355  -0.150742
# owner               0.098075   0.630589    -0.311048 -0.069644  -0.287117
# source             -0.014640   0.416384    -0.242122  0.061738  -0.212166
# url                 0.041917   0.597080    -0.243830 -0.137512  -0.315160
# geolocation_source  0.036225  -0.464174     0.204865 -0.190907   0.220812
# total_generation    0.068582  -0.260412     0.864434  0.069395   0.183977
#
#                     primary_fuel  commissioning_year     owner    source  \
# name                    0.040753           -0.041465  0.098075 -0.014640
# gppd_idnr               0.609180            0.511350  0.630589  0.416384
# capacity_mw            -0.380395           -0.004072 -0.311048 -0.242122
# latitude               -0.020203            0.035355 -0.069644  0.061738
# longitude              -0.368766           -0.150742 -0.287117 -0.212166
# primary_fuel            1.000000            0.164947  0.284296  0.053613
# commissioning_year      0.164947            1.000000  0.408917  0.322222
# owner                   0.284296            0.408917  1.000000  0.769583
# source                  0.053613            0.322222  0.769583  1.000000
# url                     0.589886            0.342155  0.419773  0.160144
# geolocation_source     -0.483217           -0.259929 -0.384838 -0.505720
# total_generation       -0.295404           -0.058174 -0.228996 -0.180750
#
#                          url  geolocation_source  total_generation
# name                0.041917            0.036225          0.068582
# gppd_idnr           0.597080           -0.464174         -0.260412
# capacity_mw        -0.243830            0.204865          0.864434
# latitude           -0.137512           -0.190907          0.069395
# longitude          -0.315160            0.220812          0.183977
# primary_fuel        0.589886           -0.483217         -0.295404
# commissioning_year  0.342155           -0.259929         -0.058174
# owner               0.419773           -0.384838         -0.228996
# source              0.160144           -0.505720         -0.180750
# url                 1.000000           -0.018929         -0.191380
# geolocation_source -0.018929            1.000000          0.145527
# total_generation   -0.191380            0.145527          1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here capacity_mw is postive correlated with total_generation,latitude,longitude,geolocation_source,other_fuel1.
#
# capacity_mw is negative correlated with commissioning_year,owner,source,primary_fuel.
#
# primary_fuel is postive correlated with name,other_fuel1,commissioning_year,owner,source.
#
# primary_fuel  is negative correlated with capacity_mw,latitude,longitude,geolocation_source and total_generation.
#
# commissioning_year,owner,source are highly correlated with each other.

# %%
for i in data.columns:
    plt.figure(figsize=[10,6])
    sns.kdeplot(data[i])

# %% [markdown]
# NOT ALL THE DATA ARE NORMALLY DISTRIBUTED ONLY PREDICTOR "LATITUDE" and "NAME" IS NORMALLY DISTRIBUTED
#
# THERE IS HIGH SKEWNESS PRESENT IN DATA WHICH NEED TO BE TREATED

# %%
for i in data.columns:
    plt.figure(figsize=(10,6))
    sns.boxplot(data[i])

# %% [markdown]
# OUTLIER IS HIGHLY PRESENT ALL THE DATA EXCEPT 'primary fuel'  ,  'latitude'  ,  'name'

# %%
data.skew()
# Out:
# name                  0.000000
# gppd_idnr             0.000000
# capacity_mw           3.123576
# latitude             -0.095721
# longitude             1.130252
# primary_fuel          0.472251
# commissioning_year   -1.714873
# owner                 1.364406
# source                1.827373
# url                   1.510537
# geolocation_source   -2.159841
# total_generation      5.101022
# dtype: float64

# %% [markdown]
# #### Removing outliers

# %% [markdown]
# Z Score _ Technique

# %%
from scipy.stats import zscore
import numpy as np

z=np.abs(zscore(data))
z.shape
# Out:
# (907, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 15,  15,  71,  80, 143, 143, 147, 179, 183, 191, 209, 209, 222,
#        244, 299, 308, 308, 321, 323, 333, 340, 342, 345, 360, 363, 364,
#        364, 371, 375, 416, 427, 444, 454, 478, 482, 484, 493, 493, 494,
#        494, 499, 519, 538, 541, 573, 577, 583, 601, 621, 638, 648, 648,
#        657, 657, 661, 669, 689, 695, 695, 706, 709, 721, 724, 726, 726,
#        728, 767, 786, 786, 788, 807, 808, 808, 818, 832, 848, 870, 871,
#        879, 880, 880, 895, 900], dtype=int64), array([ 2, 11,  8,  8,  2, 11,  2,  4,  4,  8,  2, 11,  6,  4,  8,  2, 11,
#         8,  4,  4,  4,  6,  8,  4,  2,  2, 11,  6,  2,  4,  4,  6,  6,  6,
#         2,  6,  2, 11,  2, 11,  4,  4,  6,  6,  6,  4,  6,  6,  6,  4,  2,
#        11,  2, 11,  8,  8,  8,  2, 11,  6,  6, 11, 11,  2, 11,  6,  2,  2,
#        11,  2,  6,  2, 11,  4,  8,  6,  8,  8,  8,  2, 11,  8,  8],
#       dtype=int64))

# %%
df_new=data[(z<3).all(axis=1)]
print(data.shape)
print(df_new.shape)
# Out:
# (907, 12)
# (838, 12)

# %% [markdown]
# #### percentage data loss

# %%
loss_percent=(907-838)/907*100
print(loss_percent)
# Out:
# 7.6074972436604185

# %% [markdown]
# #### removing Skewness

# %%
df1 = np.sqrt(data)

df1.head(15)
# Out:
#         name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0   0.000000  25.632011     1.581139  5.308851   8.558078      2.449490
# 1   1.000000  22.781571     9.899495  4.976575   8.637650      1.000000
# 2   1.414214  29.206164     6.260990  4.680150   8.329058      2.645751
# 3   1.732051   0.000000    11.618950  4.885816   9.558253      1.414214
# 4   2.000000   1.000000    42.426407  4.686182   9.077946      1.000000
# 5   2.236068   1.414214    15.811388  4.875336   8.285210      1.000000
# 6   2.449490   1.732051     7.745967  3.233373   8.775409      1.732051
# 7   2.645751   2.000000    13.856406  5.676777   8.786751      1.732051
# 8   2.828427   2.236068    17.029386  4.041039   8.711274      1.732051
# 9   3.000000   2.449490    14.491377  4.812920   9.035336      1.000000
# 10  3.162278   2.645751    36.742346  4.591100   8.826149      1.000000
# 11  3.316625   2.828427    11.575837  5.592111   8.746073      1.732051
# 12  3.464102   3.000000    34.641016  4.919421   9.099451      1.000000
# 13  3.605551   3.162278     4.117038  5.589383   8.824789      1.732051
# 14  3.741657   3.316625     3.000000  4.358945   8.467095      1.732051
#
#     commissioning_year      owner     source        url  geolocation_source  \
# 0            44.844175  15.132746  10.440307  11.313708            1.000000
# 1            44.888751  16.062378  13.190906  13.152946            1.414214
# 2            44.888751   1.414214   4.582576  14.317821            1.414214
# 3            44.766059   2.236068   4.690416   7.615773            1.414214
# 4            44.888751   2.236068   4.690416   7.615773            1.414214
# 5            44.777226   2.236068   4.690416   7.615773            1.414214
# 6            44.384682   2.236068   4.690416   7.615773            1.414214
# 7            44.833024   2.236068   4.690416   7.615773            1.414214
# 8            44.766059   2.236068   4.690416   7.615773            1.414214
# 9            44.810713   2.236068   4.690416   7.615773            1.414214
# 10           44.877611   2.236068   4.690416   7.615773            1.414214
# 11           44.553339   2.236068   4.690416   7.615773            1.414214
# 12           44.844175   2.236068   4.690416   7.615773            1.414214
# 13           44.564560   2.236068   4.690416   7.615773            1.414214
# 14           44.575778   2.236068   4.690416   7.615773            1.414214
#
#     total_generation
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3          60.312141
# 4         166.911652
# 5          75.250289
# 6          22.563944
# 7          57.709310
# 8          43.275962
# 9          88.996517
# 10        131.603017
# 11         54.957461
# 12        198.840502
# 13          0.000000
# 14          0.000000

# %%
df1.skew()
# Out:
# name                 -0.571302
# gppd_idnr            -0.571302
# capacity_mw           1.472953
# latitude             -0.433814
# longitude             1.032148
# primary_fuel         -0.288254
# commissioning_year   -1.724880
# owner                 1.030061
# source                1.506368
# url                   0.992063
# geolocation_source   -2.176473
# total_generation      2.126998
# dtype: float64

# %%
data=df1

# %% [markdown]
# # Make two prediction  1) Primary Fuel    2) capacity_mw

# %% [markdown]
# # 1) Primary Fuel

# %% [markdown]
# ### TEST TRAIN SPLIT

# %%
x= data.drop(columns='primary_fuel')
y= data['primary_fuel']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=123)

# %% [markdown]
# ### scaling

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# ## MODEL CONSTRUCTION

# %% [markdown]
# ### LinearRegression

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,predictions))
# Out:
# Mean Absolute Error:  0.2976833205025197
# Mean Squared Error:  0.16203666529287
# Root Mean Squared Error:  0.402537781199318
# Explained Variance Score:  0.654684820393509

# %% [markdown]
# ### FINDING BEST random_state

# %%
from sklearn.metrics import r2_score
maxAcc=0
maxRS=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lm=LinearRegression(fit_intercept=True)
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    acc=r2_score(y_test,pred)
    print('accurancy',acc, 'random_state',i)
    if acc>maxAcc:
        maxAcc=acc
        maxRs=i
    print('accurancy',maxAcc, 'random_state',i)

print('Best accurancy is ',maxAcc, ' on random_state',maxRs)
# Out:
# accurancy 0.6158109840089374 random_state 0
# accurancy 0.6158109840089374 random_state 0
# accurancy 0.5623239331297933 random_state 1
# accurancy 0.6158109840089374 random_state 1
# accurancy 0.5256150066421017 random_state 2
# accurancy 0.6158109840089374 random_state 2
# accurancy 0.5657143628848582 random_state 3
# accurancy 0.6158109840089374 random_state 3
# accurancy 0.6070539207604213 random_state 4
# accurancy 0.6158109840089374 random_state 4
# accurancy 0.5633289945887554 random_state 5
# accurancy 0.6158109840089374 random_state 5
# accurancy 0.5697469440590013 random_state 6
# accurancy 0.6158109840089374 random_state 6
# accurancy 0.4825395315672911 random_state 7
# accurancy 0.6158109840089374 random_state 7
# accurancy 0.6280059361688599 random_state 8
# accurancy 0.6280059361688599 random_state 8
# accurancy 0.5621870956613848 random_state 9
# accurancy 0.6280059361688599 random_state 9
# accurancy 0.5848712034943938 random_state 10
# accurancy 0.6280059361688599 random_state 10
# accurancy 0.5953683874634699 random_state 11
# accurancy 0.6280059361688599 random_state 11
# accurancy 0.5574938101011985 random_state 12
# accurancy 0.6280059361688599 random_state 12
# accurancy 0.6164742135001182 random_state 13
# accurancy 0.6280059361688599 random_state 13
# accurancy 0.5150864614920447 random_state 14
# accurancy 0.6280059361688599 random_state 14
# accurancy 0.5002690815468446 random_state 15
# accurancy 0.6280059361688599 random_state 15
# accurancy 0.5973507918655608 random_state 16
# accurancy 0.6280059361688599 random_state 16
# accurancy 0.6140818851176181 random_state 17
# accurancy 0.6280059361688599 random_state 17
# accurancy 0.6088303292714979 random_state 18
# accurancy 0.6280059361688599 random_state 18
# accurancy 0.5948165031721547 random_state 19
# accurancy 0.6280059361688599 random_state 19
# accurancy 0.5022583559856474 random_state 20
# accurancy 0.6280059361688599 random_state 20
# accurancy 0.5809616796781889 random_state 21
# accurancy 0.6280059361688599 random_state 21
# accurancy 0.5888453595390795 random_state 22
# accurancy 0.6280059361688599 random_state 22
# accurancy 0.6080998535535127 random_state 23
# accurancy 0.6280059361688599 random_state 23
# accurancy 0.5726825011208656 random_state 24
# accurancy 0.6280059361688599 random_state 24
# accurancy 0.4425250522842792 random_state 25
# accurancy 0.6280059361688599 random_state 25
# accurancy 0.5514430754080195 random_state 26
# accurancy 0.6280059361688599 random_state 26
# accurancy 0.5008479349158289 random_state 27
# accurancy 0.6280059361688599 random_state 27
# accurancy 0.572581528918098 random_state 28
# accurancy 0.6280059361688599 random_state 28
# accurancy 0.4592563553725595 random_state 29
# accurancy 0.6280059361688599 random_state 29
# accurancy 0.6247129730838635 random_state 30
# accurancy 0.6280059361688599 random_state 30
# accurancy 0.5552360385989766 random_state 31
# accurancy 0.6280059361688599 random_state 31
# accurancy 0.5664120817214775 random_state 32
# accurancy 0.6280059361688599 random_state 32
# accurancy 0.5706645652590889 random_state 33
# accurancy 0.6280059361688599 random_state 33
# accurancy 0.47337810841044026 random_state 34
# accurancy 0.6280059361688599 random_state 34
# accurancy 0.6041097796143117 random_state 35
# accurancy 0.6280059361688599 random_state 35
# accurancy 0.5788726313109809 random_state 36
# accurancy 0.6280059361688599 random_state 36
# accurancy 0.6250959105875729 random_state 37
# accurancy 0.6280059361688599 random_state 37
# accurancy 0.5627389543763601 random_state 38
# accurancy 0.6280059361688599 random_state 38
# accurancy 0.6581636978615626 random_state 39
# accurancy 0.6581636978615626 random_state 39
# accurancy 0.5716464440840889 random_state 40
# accurancy 0.6581636978615626 random_state 40
# accurancy 0.6045443674918274 random_state 41
# accurancy 0.6581636978615626 random_state 41
# accurancy 0.5757307060673432 random_state 42
# accurancy 0.6581636978615626 random_state 42
# accurancy 0.5069730951639452 random_state 43
# accurancy 0.6581636978615626 random_state 43
# accurancy 0.5676769442666414 random_state 44
# accurancy 0.6581636978615626 random_state 44
# accurancy 0.5192361670736976 random_state 45
# accurancy 0.6581636978615626 random_state 45
# accurancy 0.6236649762781321 random_state 46
# accurancy 0.6581636978615626 random_state 46
# accurancy 0.515785436157833 random_state 47
# accurancy 0.6581636978615626 random_state 47
# accurancy 0.635873054158385 random_state 48
# accurancy 0.6581636978615626 random_state 48
# accurancy 0.5282944736639678 random_state 49
# accurancy 0.6581636978615626 random_state 49
# accurancy 0.6315309839109512 random_state 50
# accurancy 0.6581636978615626 random_state 50
# accurancy 0.584063924194232 random_state 51
# accurancy 0.6581636978615626 random_state 51
# accurancy 0.5596689245745519 random_state 52
# accurancy 0.6581636978615626 random_state 52
# accurancy 0.5561086550514283 random_state 53
# accurancy 0.6581636978615626 random_state 53
# accurancy 0.5637642847597693 random_state 54
# accurancy 0.6581636978615626 random_state 54
# accurancy 0.5678630497326974 random_state 55
# accurancy 0.6581636978615626 random_state 55
# accurancy 0.49746804734999617 random_state 56
# accurancy 0.6581636978615626 random_state 56
# accurancy 0.481137127063616 random_state 57
# accurancy 0.6581636978615626 random_state 57
# accurancy 0.554469581819983 random_state 58
# accurancy 0.6581636978615626 random_state 58
# accurancy 0.5978011389144118 random_state 59
# accurancy 0.6581636978615626 random_state 59
# accurancy 0.6080018361822787 random_state 60
# accurancy 0.6581636978615626 random_state 60
# accurancy 0.587400769465223 random_state 61
# accurancy 0.6581636978615626 random_state 61
# accurancy 0.5192380873462321 random_state 62
# accurancy 0.6581636978615626 random_state 62
# accurancy 0.634790735440312 random_state 63
# accurancy 0.6581636978615626 random_state 63
# accurancy 0.6269760948696144 random_state 64
# accurancy 0.6581636978615626 random_state 64
# accurancy 0.5863293265942955 random_state 65
# accurancy 0.6581636978615626 random_state 65
# accurancy 0.5920574571719996 random_state 66
# accurancy 0.6581636978615626 random_state 66
# accurancy 0.6079411048435963 random_state 67
# accurancy 0.6581636978615626 random_state 67
# accurancy 0.5811210561392974 random_state 68
# accurancy 0.6581636978615626 random_state 68
# accurancy 0.45742494787265986 random_state 69
# accurancy 0.6581636978615626 random_state 69
# accurancy 0.5266317264029242 random_state 70
# accurancy 0.6581636978615626 random_state 70
# accurancy 0.5800901430303289 random_state 71
# accurancy 0.6581636978615626 random_state 71
# accurancy 0.5377301227111124 random_state 72
# accurancy 0.6581636978615626 random_state 72
# accurancy 0.6081976104827153 random_state 73
# accurancy 0.6581636978615626 random_state 73
# accurancy 0.5443442921159385 random_state 74
# accurancy 0.6581636978615626 random_state 74
# accurancy 0.5253695698846261 random_state 75
# accurancy 0.6581636978615626 random_state 75
# accurancy 0.4677061691688602 random_state 76
# accurancy 0.6581636978615626 random_state 76
# accurancy 0.5418967635748752 random_state 77
# accurancy 0.6581636978615626 random_state 77
# accurancy 0.35239290718910476 random_state 78
# accurancy 0.6581636978615626 random_state 78
# accurancy 0.6160308246777711 random_state 79
# accurancy 0.6581636978615626 random_state 79
# accurancy 0.595674302701702 random_state 80
# accurancy 0.6581636978615626 random_state 80
# accurancy 0.45834364024107144 random_state 81
# accurancy 0.6581636978615626 random_state 81
# accurancy 0.4852401152007455 random_state 82
# accurancy 0.6581636978615626 random_state 82
# accurancy 0.5499475961598668 random_state 83
# accurancy 0.6581636978615626 random_state 83
# accurancy 0.4996530589146081 random_state 84
# accurancy 0.6581636978615626 random_state 84
# accurancy 0.5925750102552634 random_state 85
# accurancy 0.6581636978615626 random_state 85
# accurancy 0.5908152968950022 random_state 86
# accurancy 0.6581636978615626 random_state 86
# accurancy 0.5235278661863793 random_state 87
# accurancy 0.6581636978615626 random_state 87
# accurancy 0.5174097596296532 random_state 88
# accurancy 0.6581636978615626 random_state 88
# accurancy 0.6109476534534036 random_state 89
# accurancy 0.6581636978615626 random_state 89
# accurancy 0.6690157919760871 random_state 90
# accurancy 0.6690157919760871 random_state 90
# accurancy 0.5768742842550969 random_state 91
# accurancy 0.6690157919760871 random_state 91
# accurancy 0.5207324907140293 random_state 92
# accurancy 0.6690157919760871 random_state 92
# accurancy 0.6545162364463428 random_state 93
# accurancy 0.6690157919760871 random_state 93
# accurancy 0.5787796156147749 random_state 94
# accurancy 0.6690157919760871 random_state 94
# accurancy 0.6364926741368834 random_state 95
# accurancy 0.6690157919760871 random_state 95
# accurancy 0.5400085901727656 random_state 96
# accurancy 0.6690157919760871 random_state 96
# accurancy 0.6259138981908149 random_state 97
# accurancy 0.6690157919760871 random_state 97
# accurancy 0.5390594944261623 random_state 98
# accurancy 0.6690157919760871 random_state 98
# accurancy 0.5993270695581838 random_state 99
# accurancy 0.6690157919760871 random_state 99
# Best accurancy is  0.6690157919760871  on random_state 90

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=90)

# %% [markdown]
# ### LinearRegression

# %%
lm = LinearRegression(fit_intercept=True, normalize=True)
lm.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
print('model coeffient :',lm.coef_)
print('model intercept :',lm.intercept_)
# Out:
# model coeffient : [-0.01503364  0.13469104 -0.09599886  0.02319573 -0.06777839 -0.15912953
#  -0.04469249 -0.25299781  0.29120406 -0.35921245 -0.0083019 ]
# model intercept : 1.6324798571549626

# %%
#predict the value
pred=lm.predict(x_test)
print('predicted result score',pred)
print('actual score',y_test)
# Out:
# predicted result score [1.60646558 1.18337886 1.60474772 2.52281636 1.18760876 1.43160102
#  1.61365602 2.26813977 2.41454269 1.38748544 1.49770231 1.81843677
#  1.11422604 2.4545352  1.29606042 1.49734463 1.33026893 1.67864774
#  1.85085302 2.59945615 0.39681404 1.39059939 1.15636116 1.42432478
#  2.35420843 2.16901097 1.49124396 1.31225402 1.67275985 1.07205492
#  1.26959957 2.39831732 1.59330039 1.02904555 0.27253334 2.43533801
#  3.52007389 1.25216562 1.66671637 1.01777397 1.53892354 1.48251431
#  1.42243948 1.61979567 2.01233002 1.31722391 1.36815211 2.57968285
#  2.30361424 2.12800827 1.62685589 0.6366868  2.50743378 1.20539178
#  2.03006155 1.34996135 1.28724201 2.30402255 1.24314634 1.374624
#  1.4918243  1.99491176 1.29864358 1.20402041 1.18828146 2.30460278
#  2.50075288 1.26054376 1.47506588 1.42506069 1.46710116 1.27208
#  2.19478133 1.28725708 1.3776937  1.18440419 1.43036572 1.09754739
#  1.33361662 1.74691019 0.58156354 1.63498628 1.31916484 1.28586803
#  1.73453683 1.62780861 1.47539704 1.77479075 1.27082138 1.83313871
#  0.98296161 2.1579009  1.61318362 2.46900489 1.64410654 1.58823042
#  1.34611934 1.87810653 0.65612001 1.60241357 2.60910917 2.48395341
#  2.1458227  2.41522421 1.23968746 0.76374743 1.91293311 1.17556201
#  1.45412426 1.63025107 1.2518791  2.34145286 2.26091667 1.28557559
#  2.49516651 1.48255212 2.24286552 2.15628141 2.25997898 1.26575215
#  1.22362057 1.63652747 2.24034587 1.41430963 2.67962367 1.30598131
#  2.2615627  1.14921791 2.06851645 1.20847751 1.4370314  1.73025213
#  1.44097566 1.31635976 1.6187399  1.23236951 1.17941565 1.17935265
#  2.42256515 1.15628046 1.88421618 2.33302138 1.5510246  1.33695433
#  1.26604647 1.08500741 0.68570351 2.25264694 2.13445101 1.25160937
#  1.66761302 1.21907304 2.12373845 1.84163503 1.35848091 1.19502695
#  1.40320343 1.93182526 2.5583004  1.94933741 2.18425401 1.30292953
#  2.20019764 1.88345694 2.63346028 1.43228926 2.49655083 2.05342392
#  1.05683399 1.04161719 1.87846425 2.69377529 1.44035475 1.30925494
#  2.34670116 0.67212597 1.2742888  1.29163211 1.35873535 1.35022447
#  1.65355131 1.71438186]
# actual score 789    1.732051
# 324    1.732051
# 83     1.732051
# 118    2.449490
# 209    1.000000
#          ...
# 366    1.000000
# 862    1.000000
# 746    1.000000
# 160    2.000000
# 701    1.732051
# Name: primary_fuel, Length: 182, dtype: float64

# %%
print(lm.score(x_test, y_test))
print(mean_squared_error(lm.predict(x_test), y_test))
# Out:
# 0.6617075782368562
# 0.16953497516452062

# %%
plt.scatter(y_test,pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('error')
#r2 score--> coefficent of determination
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absolute error : 0.32446019640003027
# mean squared error : 0.16953497516452062
# root mean squared error : 0.41174625094166994

# %% [markdown]
# C-V SCORE

# %%
lr_cv=cross_val_score(lm,x,y, cv = 6).mean()
lr_cv
# Out:
# 0.5369741527004172

# %% [markdown]
# ### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
 predictions1=rf.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,predictions1))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,predictions1))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,predictions1)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,predictions1))
print('r2_score:',r2_score(y_test,predictions1))
# Out:
# Mean Absolute Error:  0.13548223366108944
# Mean Squared Error:  0.0634487198507869
# Root Mean Squared Error:  0.2518902932841734
# Explained Variance Score:  0.8766588300262506
# r2_score: 0.8733935515355189

# %% [markdown]
# C-V SCORE

# %%
rfr_cv=cross_val_score(rf,x,y, cv = 9).mean()
rfr_cv
# Out:
# 0.8672330111748094

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
# Out:
# 0.8544108869171958

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,svr_predict))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,svr_predict))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,svr_predict)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,svr_predict))
print('r2_score:',r2_score(y_test,svr_predict))
# Out:
# Mean Absolute Error:  0.20263447979005236
# Mean Squared Error:  0.09998510787232995
# Root Mean Squared Error:  0.31620421861880643
# Explained Variance Score:  0.807472928194625
# r2_score: 0.8004883402403788

# %% [markdown]
# C-V SCORE

# %%
svr_cv=cross_val_score(svr,x,y, cv = 10).mean()
svr_cv
# Out:
# 0.7813123600278217

# %% [markdown]
# ### DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,DTR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,DTR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,DTR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,DTR_PRED))
print('r2_score:',r2_score(y_test,DTR_PRED))
# Out:
# Mean Absolute Error:  0.15818793286705693
# Mean Squared Error:  0.12816095586229617
# Root Mean Squared Error:  0.3579957483857821
# Explained Variance Score:  0.7462163603793793
# r2_score: 0.744265865541538

# %% [markdown]
# C-V SCORE

# %%
dtr_cv=cross_val_score(DTR,x,y, cv = 10).mean()
dtr_cv
# Out:
# 0.7509774900203483

# %% [markdown]
# ### GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)
# Out:
# 0.9493440156129546

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,GBR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,GBR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,GBR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,GBR_PRED))
print('r2_score:',r2_score(y_test,GBR_PRED))
# Out:
# Mean Absolute Error:  0.16482137620148293
# Mean Squared Error:  0.07441985736171845
# Root Mean Squared Error:  0.2728000318213296
# Explained Variance Score:  0.8570676828435229
# r2_score: 0.8515015928145068

# %% [markdown]
# C-V SCORE

# %%
GBR_cv=cross_val_score(GBR,x,y, cv = 10).mean()
GBR_cv
# Out:
# 0.8197731492600984

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge

R=Ridge()
R.fit(x_train,y_train)
print(R.score(x_train,y_train))
R_predict=R.predict(x_test)
# Out:
# 0.5687852954900668

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,R_predict))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,R_predict))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,R_predict)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,R_predict))
print('r2_score:',r2_score(y_test,R_predict))
# Out:
# Mean Absolute Error:  0.32460719212757005
# Mean Squared Error:  0.16962536304494905
# Root Mean Squared Error:  0.41185599794703615
# Explained Variance Score:  0.6662812527179532
# r2_score: 0.6615272170167688

# %% [markdown]
# C-V SCORE

# %%
R_cv=cross_val_score(R,x,y, cv = 10).mean()
R_cv
# Out:
# 0.529727965779728

# %% [markdown]
# ### After evaluating the model based on MAE,MSE,RMSE,EVS,R2 SCORE the 2 best models choosen for hyper parameter tuning are
#
# 1.RandomForestRegressor
#
# 2.GradientBoostingRegressor

# %% [markdown]
# ### 1.RandomForestRegressor

# %%
RF=RandomForestRegressor()
param={
     'n_estimators':[100,200,],
    'criterion':["mse", "mae"],
    'min_samples_split':[2],
   'min_samples_leaf' : [1],
}

# %%
from sklearn.model_selection import GridSearchCV
RF_grid=GridSearchCV(RandomForestRegressor(),param,cv=4)

# %%
RF_grid.fit(x_train,y_train)
RF_grid_PRED=RF_grid.best_estimator_.predict(x_test)

# %%
RF_grid.best_params_
# Out:
# {'criterion': 'mse',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
rf=RandomForestRegressor(criterion='mse',min_samples_leaf=1,min_samples_split=2,n_estimators=200)
rf.fit(x_train,y_train)
rf_predictions=rf.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,rf_predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,rf_predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,rf_predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,rf_predictions))
print('r2_score:',r2_score(y_test,rf_predictions))
# Out:
# Mean Absolute Error:  0.13039755719967017
# Mean Squared Error:  0.061650877325385975
# Root Mean Squared Error:  0.24829594705791308
# Explained Variance Score:  0.8799420159402926
# r2_score: 0.876980991243912

# %%
#CV SCORE
rfr_cv=cross_val_score(rf,x,y, cv = 5).mean()
rfr_cv
# Out:
# 0.8780854516718744

# %% [markdown]
# ### 2.GradientBoostingRegressor

# %%
parameter = {"loss":['ls', 'lad', 'huber', 'quantile'],
             "criterion":['friedman_mse', 'mse', 'mae']}
GBR = GridSearchCV(GradientBoostingRegressor(),parameter,cv=5)

# %%
GBR.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'mse', 'mae'],
#                          'loss': ['ls', 'lad', 'huber', 'quantile']})

# %%
GBR.best_params_
# Out:
# {'criterion': 'mse', 'loss': 'ls'}

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor(criterion='mse',loss='ls')
GBR.fit(x_train,y_train)
GBR_final=GBR.predict(x_test)

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,GBR_final))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,GBR_final))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,GBR_final)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,GBR_final))
print('r2_score:',r2_score(y_test,GBR_final))
# Out:
# Mean Absolute Error:  0.1648706196288111
# Mean Squared Error:  0.07430484006313488
# Root Mean Squared Error:  0.2725891414989505
# Explained Variance Score:  0.8572860414621842
# r2_score: 0.8517310999144119

# %%
#CV SCORE
GBR_cv=cross_val_score(GBR,x,y, cv = 5).mean()
GBR_cv
# Out:
# 0.8453330164074272

# %% [markdown]
# #### RandomForestRegressor HAVING HIGH R2 SCORE SO PERFORMING HYPER PARAMETER TUNING

# %%
print("THE BEST MODEL: RandomForestRegressor")
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,rf_predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,rf_predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,rf_predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,rf_predictions))
print('r2_score:',r2_score(y_test,rf_predictions))
# Out:
# THE BEST MODEL: RandomForestRegressor
# Mean Absolute Error:  0.13039755719967017
# Mean Squared Error:  0.061650877325385975
# Root Mean Squared Error:  0.24829594705791308
# Explained Variance Score:  0.8799420159402926
# r2_score: 0.876980991243912

# %%
sns.distplot((y_test-rf_predictions))
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='Density'>

# %%
df=pd.DataFrame({'Y Test':y_test , 'Prediction':-rf_predictions},columns=['Y Test','Prediction'])
sns.lmplot(x='Y Test',y='Prediction',data=df,palette='rainbow')
df.head()
# Out:
#        Y Test  Prediction
# 789  1.732051   -1.551062
# 324  1.732051   -1.477904
# 83   1.732051   -1.730462
# 118  2.449490   -2.449490
# 209  1.000000   -1.015000

# %% [markdown]
# ### SAVE THE MODEL

# %%
import joblib
joblib.dump(rf,"final model.pkl")
# Out:
# ['final model.pkl']

# %% [markdown]
# # 2) capacity_mw

# %% [markdown]
# ### Feature Engineering

# %%
y = data['capacity_mw']
x = data.drop('capacity_mw', axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=123)

# %% [markdown]
# ### SCALING

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# # MODEL CONSTRUCTION

# %% [markdown]
# ### LinearRegression

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,predictions))
# Out:
# Mean Absolute Error:  4.388115041842949
# Mean Squared Error:  40.728784113626794
# Root Mean Squared Error:  6.381910694582524
# Explained Variance Score:  0.75268827507247

# %% [markdown]
# ### FINDING BEST random_state

# %%
from sklearn.metrics import r2_score
maxAcc=0
maxRS=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lm=LinearRegression(fit_intercept=True)
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    acc=r2_score(y_test,pred)
    print('accurancy',acc, 'random_state',i)
    if acc>maxAcc:
        maxAcc=acc
        maxRs=i
    print('accurancy',maxAcc, 'random_state',i)

print('Best accurancy is ',maxAcc, ' on random_state',maxRs)
# Out:
# accurancy 0.6080382978351724 random_state 0
# accurancy 0.6080382978351724 random_state 0
# accurancy 0.5184480097476207 random_state 1
# accurancy 0.6080382978351724 random_state 1
# accurancy 0.5941304459867864 random_state 2
# accurancy 0.6080382978351724 random_state 2
# accurancy 0.5676506592404589 random_state 3
# accurancy 0.6080382978351724 random_state 3
# accurancy 0.566824850147507 random_state 4
# accurancy 0.6080382978351724 random_state 4
# accurancy 0.5463925021025764 random_state 5
# accurancy 0.6080382978351724 random_state 5
# accurancy 0.5636485142638865 random_state 6
# accurancy 0.6080382978351724 random_state 6
# accurancy 0.5725093143172195 random_state 7
# accurancy 0.6080382978351724 random_state 7
# accurancy 0.5613272225057402 random_state 8
# accurancy 0.6080382978351724 random_state 8
# accurancy 0.5810882756641123 random_state 9
# accurancy 0.6080382978351724 random_state 9
# accurancy 0.629241688326847 random_state 10
# accurancy 0.629241688326847 random_state 10
# accurancy 0.5924570122938402 random_state 11
# accurancy 0.629241688326847 random_state 11
# accurancy 0.5789104472789639 random_state 12
# accurancy 0.629241688326847 random_state 12
# accurancy 0.5760369063803905 random_state 13
# accurancy 0.629241688326847 random_state 13
# accurancy 0.5667879864650085 random_state 14
# accurancy 0.629241688326847 random_state 14
# accurancy 0.5315379305119554 random_state 15
# accurancy 0.629241688326847 random_state 15
# accurancy 0.5190930232086206 random_state 16
# accurancy 0.629241688326847 random_state 16
# accurancy 0.5180181048509549 random_state 17
# accurancy 0.629241688326847 random_state 17
# accurancy 0.6270625446365142 random_state 18
# accurancy 0.629241688326847 random_state 18
# accurancy 0.5344201397573123 random_state 19
# accurancy 0.629241688326847 random_state 19
# accurancy 0.533017017525985 random_state 20
# accurancy 0.629241688326847 random_state 20
# accurancy 0.6046773838754774 random_state 21
# accurancy 0.629241688326847 random_state 21
# accurancy 0.5383654923734318 random_state 22
# accurancy 0.629241688326847 random_state 22
# accurancy 0.5621733802873459 random_state 23
# accurancy 0.629241688326847 random_state 23
# accurancy 0.5524230606319831 random_state 24
# accurancy 0.629241688326847 random_state 24
# accurancy 0.5821755579682681 random_state 25
# accurancy 0.629241688326847 random_state 25
# accurancy 0.5783123461280364 random_state 26
# accurancy 0.629241688326847 random_state 26
# accurancy 0.5330253512632381 random_state 27
# accurancy 0.629241688326847 random_state 27
# accurancy 0.5737635598539588 random_state 28
# accurancy 0.629241688326847 random_state 28
# accurancy 0.48306686922078934 random_state 29
# accurancy 0.629241688326847 random_state 29
# accurancy 0.56297413776629 random_state 30
# accurancy 0.629241688326847 random_state 30
# accurancy 0.5844086382698894 random_state 31
# accurancy 0.629241688326847 random_state 31
# accurancy 0.46921353231568264 random_state 32
# accurancy 0.629241688326847 random_state 32
# accurancy 0.6064586206568332 random_state 33
# accurancy 0.629241688326847 random_state 33
# accurancy 0.5804094257657126 random_state 34
# accurancy 0.629241688326847 random_state 34
# accurancy 0.5361767213736257 random_state 35
# accurancy 0.629241688326847 random_state 35
# accurancy 0.5926044796051819 random_state 36
# accurancy 0.629241688326847 random_state 36
# accurancy 0.6358598790773666 random_state 37
# accurancy 0.6358598790773666 random_state 37
# accurancy 0.5311779967009077 random_state 38
# accurancy 0.6358598790773666 random_state 38
# accurancy 0.5819197447615403 random_state 39
# accurancy 0.6358598790773666 random_state 39
# accurancy 0.5295489813293444 random_state 40
# accurancy 0.6358598790773666 random_state 40
# accurancy 0.6215466564567215 random_state 41
# accurancy 0.6358598790773666 random_state 41
# accurancy 0.5252906406569661 random_state 42
# accurancy 0.6358598790773666 random_state 42
# accurancy 0.5396105189056684 random_state 43
# accurancy 0.6358598790773666 random_state 43
# accurancy 0.5421262477411646 random_state 44
# accurancy 0.6358598790773666 random_state 44
# accurancy 0.5564323200637273 random_state 45
# accurancy 0.6358598790773666 random_state 45
# accurancy 0.5231332812602492 random_state 46
# accurancy 0.6358598790773666 random_state 46
# accurancy 0.4892908601751156 random_state 47
# accurancy 0.6358598790773666 random_state 47
# accurancy 0.5133389998343496 random_state 48
# accurancy 0.6358598790773666 random_state 48
# accurancy 0.5415831249441496 random_state 49
# accurancy 0.6358598790773666 random_state 49
# accurancy 0.5786804474825773 random_state 50
# accurancy 0.6358598790773666 random_state 50
# accurancy 0.5484164553381181 random_state 51
# accurancy 0.6358598790773666 random_state 51
# accurancy 0.5310451713879344 random_state 52
# accurancy 0.6358598790773666 random_state 52
# accurancy 0.5603561220187445 random_state 53
# accurancy 0.6358598790773666 random_state 53
# accurancy 0.5414033100736626 random_state 54
# accurancy 0.6358598790773666 random_state 54
# accurancy 0.5176708549819997 random_state 55
# accurancy 0.6358598790773666 random_state 55
# accurancy 0.5637518291256328 random_state 56
# accurancy 0.6358598790773666 random_state 56
# accurancy 0.5443206980781947 random_state 57
# accurancy 0.6358598790773666 random_state 57
# accurancy 0.5264388927327823 random_state 58
# accurancy 0.6358598790773666 random_state 58
# accurancy 0.564751883022045 random_state 59
# accurancy 0.6358598790773666 random_state 59
# accurancy 0.5690976371979686 random_state 60
# accurancy 0.6358598790773666 random_state 60
# accurancy 0.5372651081638142 random_state 61
# accurancy 0.6358598790773666 random_state 61
# accurancy 0.5536439252442946 random_state 62
# accurancy 0.6358598790773666 random_state 62
# accurancy 0.5663969784160681 random_state 63
# accurancy 0.6358598790773666 random_state 63
# accurancy 0.5896087772561119 random_state 64
# accurancy 0.6358598790773666 random_state 64
# accurancy 0.4971172456764198 random_state 65
# accurancy 0.6358598790773666 random_state 65
# accurancy 0.5784242461692982 random_state 66
# accurancy 0.6358598790773666 random_state 66
# accurancy 0.523704044872093 random_state 67
# accurancy 0.6358598790773666 random_state 67
# accurancy 0.5762277421465446 random_state 68
# accurancy 0.6358598790773666 random_state 68
# accurancy 0.4788449864922003 random_state 69
# accurancy 0.6358598790773666 random_state 69
# accurancy 0.6272171970424028 random_state 70
# accurancy 0.6358598790773666 random_state 70
# accurancy 0.580454592224905 random_state 71
# accurancy 0.6358598790773666 random_state 71
# accurancy 0.6269157432780161 random_state 72
# accurancy 0.6358598790773666 random_state 72
# accurancy 0.48490849436677297 random_state 73
# accurancy 0.6358598790773666 random_state 73
# accurancy 0.5475272077310513 random_state 74
# accurancy 0.6358598790773666 random_state 74
# accurancy 0.5973066562759719 random_state 75
# accurancy 0.6358598790773666 random_state 75
# accurancy 0.5013194416205714 random_state 76
# accurancy 0.6358598790773666 random_state 76
# accurancy 0.5546565823214462 random_state 77
# accurancy 0.6358598790773666 random_state 77
# accurancy 0.5470749578379277 random_state 78
# accurancy 0.6358598790773666 random_state 78
# accurancy 0.5508041119769436 random_state 79
# accurancy 0.6358598790773666 random_state 79
# accurancy 0.5835009324918042 random_state 80
# accurancy 0.6358598790773666 random_state 80
# accurancy 0.4939185502807806 random_state 81
# accurancy 0.6358598790773666 random_state 81
# accurancy 0.5496597170230197 random_state 82
# accurancy 0.6358598790773666 random_state 82
# accurancy 0.5569412880557683 random_state 83
# accurancy 0.6358598790773666 random_state 83
# accurancy 0.517143405429598 random_state 84
# accurancy 0.6358598790773666 random_state 84
# accurancy 0.5597860658019571 random_state 85
# accurancy 0.6358598790773666 random_state 85
# accurancy 0.565512273894677 random_state 86
# accurancy 0.6358598790773666 random_state 86
# accurancy 0.5165063638146332 random_state 87
# accurancy 0.6358598790773666 random_state 87
# accurancy 0.5163513460757846 random_state 88
# accurancy 0.6358598790773666 random_state 88
# accurancy 0.4962838291284737 random_state 89
# accurancy 0.6358598790773666 random_state 89
# accurancy 0.5632620801846229 random_state 90
# accurancy 0.6358598790773666 random_state 90
# accurancy 0.6200877960489141 random_state 91
# accurancy 0.6358598790773666 random_state 91
# accurancy 0.5856129181657774 random_state 92
# accurancy 0.6358598790773666 random_state 92
# accurancy 0.567170190473384 random_state 93
# accurancy 0.6358598790773666 random_state 93
# accurancy 0.47472695523377106 random_state 94
# accurancy 0.6358598790773666 random_state 94
# accurancy 0.570493119627497 random_state 95
# accurancy 0.6358598790773666 random_state 95
# accurancy 0.6203183916317754 random_state 96
# accurancy 0.6358598790773666 random_state 96
# accurancy 0.5644983792428971 random_state 97
# accurancy 0.6358598790773666 random_state 97
# accurancy 0.6796521760070373 random_state 98
# accurancy 0.6796521760070373 random_state 98
# accurancy 0.5278209453320192 random_state 99
# accurancy 0.6796521760070373 random_state 99
# Best accurancy is  0.6796521760070373  on random_state 98

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=98)

# %% [markdown]
# ### LinearRegression

# %%
lm = LinearRegression(fit_intercept=True, normalize=True)
lm.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
print('model coeffient :',lm.coef_)
print('model intercept :',lm.intercept_)
# Out:
# model coeffient : [ 0.83179486 -0.18374944 -0.00786986 -0.21986629 -2.8001997   4.1522719
#  -2.98518271  0.10855961  0.53968801 -0.11540538  7.40413392]
# model intercept : 12.896413708731796

# %%
#predict the value
pred=lm.predict(x_test)
print('predicted result score',pred)
print('actual score',y_test)
# Out:
# predicted result score [29.16053148 13.79846531  3.59673808 21.02047904 12.9257631  10.16305937
#   5.25568086 29.32055963  1.66899345  7.15480308  9.73373507  2.25398052
#   8.66447118  5.34428112 17.70490646 21.81365596 13.32963704 23.22602996
#  13.7358002   1.32602662 20.10137036  8.50855078 30.07702277 31.48409764
#  12.02346784 26.37411322 19.98901906 28.86451432 11.87561724 12.32767095
#  17.57306514  5.32152886 31.70935856  3.04529442 16.32994466  7.35033133
#   9.51174493 15.63984172 14.23817036  6.94890022 15.24784688 -1.85174498
#  23.18408266  7.75730521  7.03327413 28.77861231  4.07253019  2.12769596
#  12.36970161 28.48087857  2.24206824 21.38118885 10.02392431 18.02855878
#   1.92969735 17.37737126  2.5256043  21.53750176  2.34377535  3.15088683
#  11.64858078 27.57580519  4.89048589 11.35923667 30.98430053 23.80512522
#  26.36333358  3.05524358  1.02697493  2.95935811 23.90095611 18.84158774
#  29.98246889  2.13956279 12.99369778  7.98285318 11.07548054  8.41649133
#   3.05321221 23.22335353  6.27444072 22.67827789  8.41465721  2.45404298
#  11.19098862  9.01572978  4.8304366   5.59402407 29.86263925 24.58519706
#   2.52768715 24.37447137 29.344511   25.25332716 28.17897417  2.69797465
#  21.85732547  6.80653874 22.14094351 18.23912601  2.65815613 12.72849296
#  17.70958696 -1.94282151 25.80169935 10.83769736 24.42166587 13.71219884
#   6.26450247 26.14655334 31.06371875 25.81203984 15.09676186  2.98911059
#   2.47549248 12.82848815  5.18255326 18.53115794 11.74596035  3.29928807
#   2.19479474  8.65303682 24.08122436 13.44572069 23.12476762  7.42671508
#  12.68072782 12.34963122  8.54187394 11.11735838 14.87894238  9.66702813
#  27.73642162  2.26902106  6.29229714  2.39708721  8.54956703 20.16058699
#  23.91343171 25.46506963 28.29551012 16.01728739 13.66754072 18.75900999
#   7.5360901  22.38831983 11.97933458 25.71497429 31.36130862 28.5284478
#  15.70264136 28.91318123 10.18413685  4.53759333  3.97491214  6.74584336
#   2.57483787 31.08242605  1.83553409  3.27727803 25.31430314 20.06130241
#  29.10746073 10.31673194 12.88086683  7.65426495  6.0483388  28.60745298
#   3.80235573 14.81334425  4.80996072  2.64953803  2.80393176 23.91010623
#   6.24215478 27.16036651 14.89466522 18.47470566  8.61752531 12.09644913
#  18.61321793 29.64877033]
# actual score 476    24.494897
# 739    11.401754
# 584     3.162278
# 333    17.058722
# 330    15.000000
#          ...
# 92      8.660254
# 303     5.744563
# 496     3.346640
# 360    14.142136
# 448    34.641016
# Name: capacity_mw, Length: 182, dtype: float64

# %%
print(lm.score(x_test, y_test))
print(mean_squared_error(lm.predict(x_test), y_test))
# Out:
# 0.6846868940314097
# 57.60674218270639

# %%
plt.scatter(y_test,pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('error')
#r2 score--> coefficent of determination
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absolute error : 5.516510785341975
# mean squared error : 57.60674218270639
# root mean squared error : 7.5899105516933725

# %% [markdown]
# C-V score

# %%
lr_cv=cross_val_score(lm,x,y, cv = 6).mean()
lr_cv
# Out:
# 0.5611929346876227

# %% [markdown]
# ### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
 predictions1=rf.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,predictions1))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,predictions1))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,predictions1)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,predictions1))
print('r2_score:',r2_score(y_test,predictions1))
# Out:
# Mean Absolute Error:  3.1666064766597373
# Mean Squared Error:  22.397357871074988
# Root Mean Squared Error:  4.732584692435518
# Explained Variance Score:  0.8785549700144011
# r2_score: 0.8774070497960084

# %% [markdown]
# C-V score

# %%
rfr_cv=cross_val_score(rf,x,y, cv = 9).mean()
rfr_cv
# Out:
# 0.8395700965681402

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
# Out:
# 0.5169681288259405

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,svr_predict))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,svr_predict))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,svr_predict)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,svr_predict))
print('r2_score:',r2_score(y_test,svr_predict))
# Out:
# Mean Absolute Error:  5.528829735853565
# Mean Squared Error:  76.80347396376807
# Root Mean Squared Error:  8.763759122874617
# Explained Variance Score:  0.6540540257154519
# r2_score: 0.5796127153331112

# %% [markdown]
# C-V SCORE

# %%
svr_cv=cross_val_score(svr,x,y, cv = 10).mean()
svr_cv
# Out:
# 0.5530590951787235

# %% [markdown]
# ### DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,DTR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,DTR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,DTR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,DTR_PRED))
print('r2_score:',r2_score(y_test,DTR_PRED))
# Out:
# Mean Absolute Error:  4.3736118476552805
# Mean Squared Error:  46.40876648455565
# Root Mean Squared Error:  6.812397998102845
# Explained Variance Score:  0.7533473009091918
# r2_score: 0.7459795199317973

# %% [markdown]
# C-V SCORE

# %%
dtr_cv=cross_val_score(DTR,x,y, cv = 4).mean()
dtr_cv
# Out:
# 0.7304965246651481

# %% [markdown]
# ### GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)
# Out:
# 0.9327810619665612

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,GBR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,GBR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,GBR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,GBR_PRED))
print('r2_score:',r2_score(y_test,GBR_PRED))
# Out:
# Mean Absolute Error:  2.876221310344922
# Mean Squared Error:  19.011357126763095
# Root Mean Squared Error:  4.360201500706486
# Explained Variance Score:  0.8968422807868857
# r2_score: 0.8959404778470994

# %% [markdown]
# C-V SCORE

# %%
GBR_cv=cross_val_score(GBR,x,y, cv = 8).mean()
GBR_cv
# Out:
# 0.834388951423333

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge

R=Ridge()
R.fit(x_train,y_train)
print(R.score(x_train,y_train))
R_predict=R.predict(x_test)
# Out:
# 0.5332281081898824

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,R_predict))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,R_predict))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,R_predict)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,R_predict))
print('r2_score:',r2_score(y_test,R_predict))
# Out:
# Mean Absolute Error:  5.519596048254685
# Mean Squared Error:  57.65631194866816
# Root Mean Squared Error:  7.593175353478159
# Explained Variance Score:  0.6867606634520541
# r2_score: 0.6844155716778912

# %% [markdown]
# C-V SCORE

# %%
R_cv=cross_val_score(R,x,y, cv = 7).mean()
R_cv
# Out:
# 0.5563622971881061

# %% [markdown]
# # After evaluating the model based on MAE,MSE,RMSE,EVS,R2 SCORE the 3 best models choosen for hyper parameter tuning are
# 1.RandomForestRegressor
#
# 2.GradientBoostingRegressor
#
# 3.DecisionTreeRegressor

# %% [markdown]
# # 5.Hyper Parameter Tuning

# %% [markdown]
# ### RandomForestRegressor

# %%
RF=RandomForestRegressor()
param={
     'n_estimators':[100,200,],
    'criterion':["mse", "mae"],
    'min_samples_split':[2],
   'min_samples_leaf' : [1],
}

# %%
from sklearn.model_selection import GridSearchCV
RF_grid=GridSearchCV(RandomForestRegressor(),param,cv=4)

# %%
RF_grid.fit(x_train,y_train)
RF_grid_PRED=RF_grid.best_estimator_.predict(x_test)

# %%
RF_grid.best_params_
# Out:
# {'criterion': 'mse',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
rf=RandomForestRegressor(criterion='mse',min_samples_leaf=1,min_samples_split=2,n_estimators=200)
rf.fit(x_train,y_train)
rf_predictions=rf.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,rf_predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,rf_predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,rf_predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,rf_predictions))
print('r2_score:',r2_score(y_test,rf_predictions))
# Out:
# Mean Absolute Error:  3.1176158871082325
# Mean Squared Error:  22.569413788985596
# Root Mean Squared Error:  4.750727711518057
# Explained Variance Score:  0.8773814917048247
# r2_score: 0.876465293955961

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
parameter = {"max_depth":[1,3,5,7,9,11,12],
             'criterion':['mse','friedman_mse']}
GCV = GridSearchCV(DecisionTreeRegressor(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'friedman_mse'],
#                          'max_depth': [1, 3, 5, 7, 9, 11, 12]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 7}

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor(criterion='friedman_mse',max_depth=5)
DTR.fit(x_train,y_train)
DTR_final=DTR.predict(x_test)

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,DTR_final))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,DTR_final))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,DTR_final)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,DTR_final))
print('r2_score:',r2_score(y_test,DTR_final))
# Out:
# Mean Absolute Error:  3.639597888845993
# Mean Squared Error:  28.76256453946704
# Root Mean Squared Error:  5.363074168745668
# Explained Variance Score:  0.8429211568864776
# r2_score: 0.8425668035210647

# %% [markdown]
# ### GradientBoostingRegressor

# %%
parameter = {"loss":['ls', 'lad', 'huber', 'quantile'],
             "criterion":['friedman_mse', 'mse', 'mae']}
GBR = GridSearchCV(GradientBoostingRegressor(),parameter,cv=5)

# %%
GBR.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'mse', 'mae'],
#                          'loss': ['ls', 'lad', 'huber', 'quantile']})

# %%
GBR.best_params_
# Out:
# {'criterion': 'mse', 'loss': 'huber'}

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor(criterion='mse',loss='ls')
GBR.fit(x_train,y_train)
GBR_final=GBR.predict(x_test)

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,GBR_final))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,GBR_final))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,GBR_final)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,GBR_final))
print('r2_score:',r2_score(y_test,GBR_final))
# Out:
# Mean Absolute Error:  2.8896319486439066
# Mean Squared Error:  19.1341324263081
# Root Mean Squared Error:  4.374257928644366
# Explained Variance Score:  0.8961924847000113
# r2_score: 0.8952684616981393

# %% [markdown]
# ### THE BEST MODEL AFTER HYPER PARAMETER TUNING IS GradientBoostingRegressor

# %%
print("FINAL MODEL")
print("-----------------------------------------")
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,GBR_final))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,GBR_final))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,GBR_final)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,GBR_final))
print('r2_score:',r2_score(y_test,GBR_final))
# Out:
# FINAL MODEL
# -----------------------------------------
# Mean Absolute Error:  2.8896319486439066
# Mean Squared Error:  19.1341324263081
# Root Mean Squared Error:  4.374257928644366
# Explained Variance Score:  0.8961924847000113
# r2_score: 0.8952684616981393

# %%
sns.distplot(GBR_final-y_test)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %%
plt.scatter(GBR_final,y_test)
plt.plot(y_test,y_test,linewidth=4,color='Red')

# %% [markdown]
# ## SAVING THE MODEL

# %%
import joblib
joblib.dump(GBR,"final model.pkl")
# Out:
# ['final model.pkl']
