# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# # 1.Data analysis

# %%
import pandas as pd 
df=pd.read_csv('baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Input features:

# %% [markdown]
# R-  Runs(),
#
# AB -At Bats,
#
# H-  Hits,
#
# 2B- Doubles,
#
# 3B- Triples,
#
# HR -Homeruns,
#
# BB- Walks,
#
# SO- Strikeouts,
#
# SB- Stolen Bases,
#
# RA- Runs Allowed,
#
# ER- Earned Runs,
#
# ERA-Earned Run Average (ERA),
#
# SHO-Shutouts,
#
# SV- Saves,
#
# CG- Complete Games and
#
# E-  Errors
#
# OUTPUT features:
#
# W-Number of predicted wins

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# INFERENCE: Dataset doesn't have any null value

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# INFERENCE: heat map to visualize Dataset doesn't have any null value

# %%
#the complete information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Describing Datasets
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # 2.EDA

# %%
#import libraries required
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(df['CG'])
plt.title('CG')
# Out:
# Text(0.5, 1.0, 'CG')

# %%
for i in df.columns:
    plt.figure(figsize=[10,6])
    sns.kdeplot(x=i,data=df)

# %% [markdown]
# Doubles are left-skewed with wins
#
# Triple is right-skewed with wins
#
# The home run  data is right-skewed with wins
#
# Strikeout dataset is left-skewed
#
# Earned Run Average (ERA)  data is right-skewed.
#
# Shutouts data is right-skewed.
#
# Errors data is right-skewed

# %%
for i in df.columns:
    plt.figure(figsize=[10,6])
    sns.regplot(x=i,y=df['W'],data=df)

# %% [markdown]
# Run and win are linearly correlated.
#
# At balls is very weekly related to Wins.
#
# Hits are also very weekly related to winning.
#
# Doubles are linearly related with Wins.
#
# Triple has very weak negative correlations with win.
#
# The home run has a very low correlation with wins.
#
# Walk is lightly correlated to win.
#
# Strikeout is not correlated to win.
#
# Runs Allowed is highly correlated to win.
#
# Earned Runs is highly correlated to win.
#
# Earned Run Average (ERA) is not correlated to win.
#
# Shutouts are highly correlated to win with.
#
# Saves are lightly correlated to win.
#
# Errors are not correlated to wins.

# %%
#plot histogram
df.hist(bins=20,figsize=(15,20))
#plot showing
plt.show()

# %%
for i in df.columns:
    plt.figure(figsize=[10,6])
    sns.scatterplot(x=i,y=df['W'],data=df)

# %%
# Outlier Analysis
for i, col in enumerate(df.columns):
    plt.figure(i)
    sns.boxplot(df[col])

# %% [markdown]
# Runs,Error has outliers.

# %% [markdown]
# ### correlation

# %%
corr=df.corr()
corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(17,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# The number of runs, home runs, doubles, Saves, Shutouts, and Walks are highly positively  correlated with wins.
#
# Stolen Bases, Runs Allowed, Earned Runs,-Earned Run Average,Triples are highly negative  correlated with wins.
#
# The remaining features have less to no  correlation with no of Wins.
# max correlation :Saves, Shutouts
#
# min correlation: Runs Allowed, Earned Runs,-Earned Run Average

# %% [markdown]
# # PRE-PROCESSING

# %% [markdown]
# ### Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# ### Reducing skewness
# Square root Technique

# %%
#skewnes remove by using square root method
df['R']=np.sqrt(df['R'])

# %% [markdown]
# ### Removing outliers
# Z Score_Technique

# %%
#import libray
from scipy.stats import zscore
import numpy as np

z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# #### percentage data loss

# %%
loss_percent=(30-29)/30*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [markdown]
# 3.33% data is loss by removing outliers

# %%
#dividing data in feauture and vector
x=df.drop(['W'],axis=1)
y=df['W']

# %% [markdown]
# ### scaling data

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaledX= scaler.fit_transform(x)

# %% [markdown]
# ## Test Train Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (22, 16)
# (22,)
# (8, 16)
# (8,)

# %% [markdown]
# # MODEL CONSTRUCTION
# LinearRegression

# %%
lm=LinearRegression(fit_intercept=True, normalize=True)
lm.fit(x_train,y_train)
print('model coeffient :',lm.coef_)
print('model intercept :',lm.intercept_)
lm.score(x_train,y_train)
pred=lm.predict(x_test)
# Out:
# model coeffient : [  7.27852577  -1.59374784   0.41437281  -2.49841255   0.94011455
#   -1.34967793  -1.37192789  -0.03452245   0.32316982  15.86873783
#   -0.76294903 -19.50206829   2.28610128   1.12877083   7.16300479
#   -1.1079284 ]
# model intercept : 81.72437797869958

# %%
import numpy as np
from sklearn import metrics
print('error')
#r2 score--> coefficent of determination
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,pred))
# Out:
# error
# mean absolute error : 3.93478522190303
# mean squared error : 25.267034774473267
# root mean squared error : 5.026632548185044
# Explained Variance Score:  0.8841709014292612

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.8297799762561802

# %% [markdown]
# # FINDING BEST random_state

# %%
maxAcc=0
maxRS=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lm=LinearRegression(fit_intercept=True, normalize=True)
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    acc=r2_score(y_test,pred)
    print('accurancy',acc, 'random_state',i)
    if acc>maxAcc:
        maxAcc=acc
        maxRs=i
    print('accurancy',maxAcc, 'random_state',i)

print('Best accurancy is ',maxAcc, ' on random_state',maxRs)
# Out:
# accurancy 0.45122331066550336 random_state 0
# accurancy 0.45122331066550336 random_state 0
# accurancy 0.16158089424874833 random_state 1
# accurancy 0.45122331066550336 random_state 1
# accurancy -1.8282585390609793 random_state 2
# accurancy 0.45122331066550336 random_state 2
# accurancy 0.5877214738373632 random_state 3
# accurancy 0.5877214738373632 random_state 3
# accurancy 0.5881733956810382 random_state 4
# accurancy 0.5881733956810382 random_state 4
# accurancy 0.8107372834689477 random_state 5
# accurancy 0.8107372834689477 random_state 5
# accurancy 0.7639756968717384 random_state 6
# accurancy 0.8107372834689477 random_state 6
# accurancy 0.46603921933788595 random_state 7
# accurancy 0.8107372834689477 random_state 7
# accurancy 0.6094969283693161 random_state 8
# accurancy 0.8107372834689477 random_state 8
# accurancy 0.8274986808529833 random_state 9
# accurancy 0.8274986808529833 random_state 9
# accurancy 0.33596465005538245 random_state 10
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=29)

# %% [markdown]
# # 1.LinearRegression

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
print('model coeffient :',lm.coef_)
print('model intercept :',lm.intercept_)
lm.score(x_train,y_train)
pred=lm.predict(x_test)
print(pred)
# Out:
# model coeffient : [  8.21246894  -3.08031023   1.15504091  -3.04854052   1.27378256
#   -2.35616983  -0.69573161   0.31641294  -0.13455837   3.49805466
#   22.93949812 -31.72211829   2.31135545   0.39492518   4.86225685
#    0.0329879 ]
# model intercept : 80.74406957140843
# [94.90378468 82.40432453 70.22725052 65.73973045 82.93897894 75.10801802]

# %%
import numpy as np
from sklearn import metrics
print('error')
#r2 score--> coefficent of determination
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,pred))
# Out:
# error
# mean absolute error : 3.1683952967544897
# mean squared error : 15.02349104644179
# root mean squared error : 3.876014840843852
# Explained Variance Score:  0.8902099208990717

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.88034387662126

# %% [markdown]
# C-V score

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lm,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross folf{j}, the cv score is{cv_mean}")
# Out:
# At cross folf2, the cv score is-0.8690791519338263
# At cross folf3, the cv score is-0.023630914110649104
# At cross folf4, the cv score is0.26958693388060884
# At cross folf5, the cv score is0.07398575228148588
# At cross folf6, the cv score is0.23675209333017855
# At cross folf7, the cv score is0.3858221339929691
# At cross folf8, the cv score is0.3464568009208674
# At cross folf9, the cv score is-5.3061683219531455

# %%
lm_cv=cross_val_score(lm,x,y, cv = 5).mean()
lm_cv
# Out:
# 0.07398575228148588

# %% [markdown]
# ## 2. RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predictions1=rf.predict(x_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,predictions1))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,predictions1))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,predictions1)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,predictions1))
print('r2_score:',r2_score(y_test,predictions1))
# Out:
# Mean Absolute Error:  5.0083333333333355
# Mean Squared Error:  37.998716666666674
# Root Mean Squared Error:  6.164309910011555
# Explained Variance Score:  0.7320900663716813
# r2_score: 0.6973553539823008

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(rf,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross folf{j}, the cv score is{cv_mean}")
# Out:
# At cross folf2, the cv score is-0.2709711193611677
# At cross folf3, the cv score is0.430122556942442
# At cross folf4, the cv score is0.41856953770218147
# At cross folf5, the cv score is-0.5435685896790038
# At cross folf6, the cv score is0.21288386938758866
# At cross folf7, the cv score is0.03978759520916976
# At cross folf8, the cv score is-0.10748050416632998
# At cross folf9, the cv score is-11.71725566242639

# %%
rfr_cv=cross_val_score(rf,x,y, cv = 5).mean()
rfr_cv
# Out:
# -0.6032031533331209

# %% [markdown]
# ## 3.SVR

# %%
from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
# Out:
# 0.22551751024241362

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,svr_predict))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,svr_predict))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,svr_predict)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,svr_predict))
print('r2_score:',r2_score(y_test,svr_predict))
# Out:
# Mean Absolute Error:  9.069229222426985
# Mean Squared Error:  108.90507041625226
# Root Mean Squared Error:  10.435759216092151
# Explained Variance Score:  0.14331324850779636
# r2_score: 0.13261448341038018

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(svr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross folf{j}, the cv score is{cv_mean}")
# Out:
# At cross folf2, the cv score is-0.045092653048012576
# At cross folf3, the cv score is-0.05291879574533324
# At cross folf4, the cv score is-0.10536212847721263
# At cross folf5, the cv score is-0.3779157415824068
# At cross folf6, the cv score is-0.016889866631329593
# At cross folf7, the cv score is-0.2827868162377623
# At cross folf8, the cv score is-0.31990228401472187
# At cross folf9, the cv score is-23.55973924147144

# %% [markdown]
# ## 4.DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,DTR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,DTR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,DTR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,DTR_PRED))
print('r2_score:',r2_score(y_test,DTR_PRED))
# Out:
# Mean Absolute Error:  5.333333333333333
# Mean Squared Error:  37.0
# Root Mean Squared Error:  6.082762530298219
# Explained Variance Score:  0.7486725663716813
# r2_score: 0.7053097345132744

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(DTR,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross folf{j}, the cv score is{cv_mean}")
# Out:
# At cross folf2, the cv score is-0.8853529068845307
# At cross folf3, the cv score is-0.10933734165676394
# At cross folf4, the cv score is-0.08993405944712893
# At cross folf5, the cv score is-1.47893296512512
# At cross folf6, the cv score is-0.5303041504308663
# At cross folf7, the cv score is-1.4157871551510415
# At cross folf8, the cv score is-2.0783642132632014
# At cross folf9, the cv score is-12.126704243685005

# %% [markdown]
# # 5. GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)
# Out:
# 0.9999996696292867

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,GBR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,GBR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,GBR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,GBR_PRED))
print('r2_score:',r2_score(y_test,GBR_PRED))
# Out:
# Mean Absolute Error:  4.657700046075253
# Mean Squared Error:  28.712732884360793
# Root Mean Squared Error:  5.358426344026835
# Explained Variance Score:  0.8437930525701138
# r2_score: 0.7713145168502238

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(GBR,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross folf{j}, the cv score is{cv_mean},given")
# Out:
# At cross folf2, the cv score is-0.6408909310588364,given
# At cross folf3, the cv score is0.32188921767157697,given
# At cross folf4, the cv score is0.2841975102514954,given
# At cross folf5, the cv score is-1.095413366296026,given
# At cross folf6, the cv score is-0.018620703817892475,given
# At cross folf7, the cv score is-0.4312335140646491,given
# At cross folf8, the cv score is-0.8767841494648245,given
# At cross folf9, the cv score is-9.744028631044458,given

# %% [markdown]
# #### LINEAR REGRESSION HAVING HIGH R2 SCORE SO PERFORMING HYPER PARAMETER TUNING

# %% [markdown]
# # HYPER PARAMETER TUNING

# %% [markdown]
# #### LINEAR REGRESSION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,0.1,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_decision=ls.predict(x_test)
lss=r2_score(y_test,pred_decision)
print('R2 Score:',lss*100)
lsscore=cross_val_score(ls,x,y,cv=5)
lsc=lsscore.mean()
print('Cross Val Score:',lsc*100)
# Out:
# R2 Score: 89.10743699089058
# Cross Val Score: 52.614042123780635

# %%
from sklearn.linear_model import Lasso,Ridge
parameters={'alpha':[.0001,.001,0.1,.1,1,10],'random_state':list(range(0,10))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
rd=Ridge(alpha=1,random_state=0)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_decision=rd.predict(x_test)
rdg=r2_score(y_test,pred_decision)
print('R2 Score:',lss*100)
rdgcore=cross_val_score(ls,x,y,cv=5)
rdc=rdgcore.mean()
print('Cross Val Score:',rdc*100)
# Out:
# R2 Score: 89.10743699089058
# Cross Val Score: 52.614042123780635

# %%
sns.distplot((y_test-pred_decision))
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
data=pd.DataFrame({'Y Test':y_test , 'Prediction':pred_decision},columns=['Y Test','Prediction'])
sns.lmplot(x='Y Test',y='Prediction',data=data,palette='rainbow')
data.head()
# Out:
#     Y Test  Prediction
# 16      98   90.980028
# 20      90   85.418653
# 18      68   71.850132
# 23      67   68.565313
# 27      79   80.995428

# %% [markdown]
# FINAL MODEL IS CONSTRUCTED WITH ACURACY OF 89%

# %%
print("FINAL MODEL")
print("-----------------------------------------")
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,pred))
print('r2_score:',r2_score(y_test,pred))
# Out:
# FINAL MODEL
# -----------------------------------------
# mean absolute error : 3.1683952967544897
# mean squared error : 15.02349104644179
# root mean squared error : 3.876014840843852
# Explained Variance Score:  0.8902099208990717
# r2_score: 0.88034387662126

# %%
import joblib
joblib.dump(ls,"final model.pkl")
# Out:
# ['final model.pkl']
