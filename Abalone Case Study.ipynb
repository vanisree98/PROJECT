# %% [markdown]
# # Abalone Case Study

# %% [markdown]
# # Data analysis

# %%
import pandas as pd 
df=pd.read_csv('abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# # About columns

# %% [markdown]
# The variable description is produced here from abalone.names file:
#
# Name / Data Type / Measurement Unit / Description
#
# Sex / nominal / -- / M, F, and I (infant)
#
# Length / continuous / mm / Longest shell measurement
#
# Diameter / continuous / mm / perpendicular to length
#
# Height / continuous / mm / with meat in shellWhole
#
# weight / continuous / grams / whole abalone
#
# Shucked weight / continuous / grams / weight of meat
#
# Viscera weight / continuous / grams / gut weight (after bleeding)
#
# Shell weight / continuous / grams / after being dried
#
# Rings / integer / -- / +1.5 gives the age in years

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
print(df.isnull().sum())
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
print(df['Sex'].value_counts())
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
print(df['Rings'].value_counts())
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 26      1
# 29      1
# 25      1
# 1       1
# 2       1
# Name: Rings, dtype: int64

# %% [markdown]
# # EDA

# %%
#import libraries required
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
sns.countplot(df['Sex'])
plt.title('Sex')
# Out:
# Text(0.5, 1.0, 'Sex')

# %%
num=['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']

# %%
df.hist(figsize=(20,10), grid=False, layout=(2, 4), bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'Diameter'}>,
#         <AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Whole weight'}>],
#        [<AxesSubplot:title={'center':'Shucked weight'}>,
#         <AxesSubplot:title={'center':'Viscera weight'}>,
#         <AxesSubplot:title={'center':'Shell weight'}>,
#         <AxesSubplot:title={'center':'Rings'}>]], dtype=object)

# %%
plt.figure(figsize=(12,8))
sn = sns.countplot(x='Rings',data=df, hue='Sex', palette=['pink','crimson',"Yellow"])

# %%
sns.pairplot(df,hue = "Sex",palette= "coolwarm")

# %% [markdown]
# # correlation

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome of correlation
# From heatmap salary dataset has positive correlation .
#
# 1.shell weight has 63 percent correlation with Rings column which can be considered as a good bond.
#
# 2.Viscera weight has 5 percent correlation with Rings column which can be considered as a bad bond.
#
# 3.Shucked weight has 42 percent correlation with Rings column which can be
#
# considered as a good bond.
#
# 4.Whole weight has 54 percent correlation with Rings column which can be
#
# considered as a good bond.
#
# 5.Height has 56 percent correlation with Rings column which can be considered as a good bond.
#
# 6.lenght has 56 percent correlation with Rings column which can be considered as a good bond.
#
# 7.diameter has 57 percent correlation with Rings column which can be considered as a good bond.
#
#
# shell weight > Diameter > Height > length > Whole Weight > Viscera weight > Shrunk Weight.

# %% [markdown]
# # Pre processing

# %%
abalone = pd.get_dummies(df, columns=['Sex'])
abalone.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings  Sex_F  Sex_I  Sex_M
# 0         0.150     15      0      0      1
# 1         0.070      7      0      0      1
# 2         0.210      9      1      0      0
# 3         0.155     10      0      0      1
# 4         0.055      7      0      1      0

# %% [markdown]
# # Outliers checking

# %%
num=['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']

# %%
for i, col in enumerate(df[(num)]):
    plt.figure(i)
    sns.boxplot(df[col])

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve

# %%
for i, col in enumerate(df[(num)]):
    plt.figure(i)
    sns.distplot(df[col])

# %% [markdown]
# # Transforming data to remove skewness:

# %%
y = abalone['Rings']
X = abalone.drop(columns=['Rings'])

# %%
from sklearn.preprocessing import power_transform
X=power_transform(X,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)

# %% [markdown]
# # Evaluation metrics

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.
#  10.93526984 15.8120759  10.06802771 15.56225435  6.68265922  6.72962808
#  14.2438207  10.18941203  8.162027    7.93951154  7.1590267   6.0335249
#   6.7105091  10.07599437  9.03874755  7.82902099 13.54068115  6.67981089
#   9.14470446 11.72214663 11.72217467  7.64566753  7.9859864  10.06199923
#  14.3056062   7.18863596  9.22466964  9.86451807  9.81506605  7.61930518
#  13.12482791  9.24392467 10.6324184  11.3923546   9.59086211 14.56171472
#   9.07652028 15.63823791  9.70769654 15.78848492  9.73244258  8.3094104
#   9.43472089 13.61568704  7.48381092  6.04687472 10.68341975  7.80438724
#   7.73645511  8.65409942  7.49728424 11.34073073 13.41309914  6.651428
#   9.81643137  9.15985208  9.90319707  9.2153168   6.0697249   9.39140531
#   7.3045994  12.41559043 12.36479085  5.9207021   9.08146473  9.08669952
#  11.14029685 11.30178204 13.08805109  9.17208694  7.50076972 13.16077159
#   6.03098881  8.88437169  8.02782688  6.88055951  7.39095805 12.81776792
#  10.18159206 12.69823017 12.31772022  8.32941418  9.74825109 10.65416348
#   9.2594292   7.52810914 10.58103991  9.85272595 10.41357677 11.22780579
#  14.32143983  9.19762634]
# actual score 2812     5
# 1344    10
# 533      9
# 866      9
# 3939    14
#         ..
# 1886     9
# 3724     7
# 1203    12
# 3889    12
# 2597     8
# Name: Rings, Length: 836, dtype: int64

# %%
print(lm.score(X_test, y_test))
print(mean_squared_error(lm.predict(X_test), y_test))
# Out:
# 0.5531589087674971
# 4.454406529323329

# %%
plt.scatter(y_test,pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('error')
#r2 score--> coefficent of determination
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absolute error : 1.5134424770445563
# mean squared error : 4.454406529323329
# root mean squared error : 2.1105465001566133

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso,Ridge
ls=Lasso(fit_intercept=True, normalize=True, alpha=0.001)
ls.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, normalize=True)

# %%
print(ls.score(X_train,y_train))
print(mean_squared_error(ls.predict(X_test), y_test))
# Out:
# 0.522874738998027
# 4.626691026902243

# %%
print('mean absolute error :',mean_absolute_error(y_test,pred))
print('mean squared error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error : 1.5134424770445563
# mean squared error : 4.454406529323329
# root mean squared error : 2.1105465001566133

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5531589087674971

# %% [markdown]
# # Ridge Regression

# %%
rm = Ridge(fit_intercept=True, normalize=True, alpha=0.5)
rm.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5, normalize=True)

# %%
print(rm.score(X_test, y_test))
print(mean_squared_error(rm.predict(X_test), y_test))
# Out:
# 0.427859552778998
# 5.70347309993728

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5531589087674971

# %% [markdown]
# # GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
print(gbr.score(X_test, y_test))
print(mean_squared_error(gbr.predict(X_test), y_test))
# Out:
# 0.5331786541980712
# 4.653582876704693

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
y_rf = rf.predict(X_test)
print(rf.score(X_test,y_test))
# Out:
# 0.5467553296543045

# %%
predictions1=rf.predict(X_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,predictions1))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,predictions1))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,predictions1)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,predictions1))
print('r2_score:',r2_score(y_test,predictions1))
# Out:
# Mean Absolute Error:  1.4912918660287082
# Mean Squared Error:  4.518241626794258
# Root Mean Squared Error:  2.125615587728472
# Explained Variance Score:  0.5468955879786239
# r2_score: 0.5467553296543045

# %%
from sklearn.ensemble import RandomForestClassifier
# creating the model
model_rfc = RandomForestClassifier(n_estimators = 200)

# feeding the training set into the model
model_rfc.fit(X_train, y_train)

# predicting the results for the test set
y_pred = model_rfc.predict(X_test)

# calculating the training and testing accuracies
print("Training accuracy :", model_rfc.score(X_train, y_train))
print("Testing accuracy :", model_rfc.score(X_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy : 0.23564593301435408

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR

svr=SVR()
svr.fit(X_train,y_train)
print(svr.score(X_train,y_train))
svr_predict=svr.predict(X_test)
# Out:
# 0.547851589453145

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,svr_predict))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,svr_predict))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,svr_predict)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,svr_predict))
print('r2_score:',r2_score(y_test,svr_predict))
# Out:
# Mean Absolute Error:  1.4205557986342336
# Mean Squared Error:  4.585787339933566
# Root Mean Squared Error:  2.141445152212301
# Explained Variance Score:  0.5584258509668749
# r2_score: 0.5399795223792935

# %%
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
# creating the model
model_svc = SVC()

# feeding the training set into the model
model_svc.fit(X_train, y_train)

# predicting the results for the test set
y_pred = model_svc.predict(X_test)

# %%
svc_cv = cross_val_score(estimator = model_svc, X = X_train, y = y_train, cv = 10)
svc_cv.mean()
# Out:
# 0.2625087139154527

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import GridSearchCV, cross_val_score
# creating model
model_dt = DecisionTreeClassifier()

# feeding the training set into the model
model_dt.fit(X_train, y_train)

# predicting the results for the test set
y_pred = model_dt.predict(X_test)

# calculating the training and testing accuracies
print("Training accuracy :", model_dt.score(X_train, y_train))
print("Testing accuracy :", model_dt.score(X_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy : 0.20574162679425836

# %%
#Now lets try to do some evaluation for decision tree model using cross validation.

dt_cv = cross_val_score(estimator = model_dt, X = X_train, y= y_train, cv = 10)
dt_cv.mean()
# Out:
# 0.19725355259629995

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(X_train,y_train)
print(DTR.score(X_train,y_train))
DTR_PRED=DTR.predict(X_test)
# Out:
# 1.0

# %%
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,DTR_PRED))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,DTR_PRED))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,DTR_PRED)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,DTR_PRED))
print('r2_score:',r2_score(y_test,DTR_PRED))
# Out:
# Mean Absolute Error:  2.0095693779904304
# Mean Squared Error:  8.688995215311005
# Root Mean Squared Error:  2.947710164739913
# Explained Variance Score:  0.12892045076141212
# r2_score: 0.12836871126053817

# %% [markdown]
# ### After evaluating the model based on MAE,MSE,RMSE,EVS,R2 SCORE the 3 best models choosen for hyper parameter tuning are
# 1.RandomForestRegressor
# 2.SVR

# %% [markdown]
# # Hyper Parameter Tuning
# RandomForestRegressor

# %%
RF=RandomForestRegressor()
param={
     'n_estimators':[100,200,],
    'criterion':["mse", "mae"],
    'min_samples_split':[2],
   'min_samples_leaf' : [1],
}

# %%
from sklearn.model_selection import GridSearchCV
RF_grid=GridSearchCV(RandomForestRegressor(),param,cv=4)


RF_grid.fit(X_train,y_train)
RF_grid_PRED=RF_grid.best_estimator_.predict(X_test)

# %%
RF_grid.best_params_
# Out:
# {'criterion': 'mae',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
rf=RandomForestRegressor(criterion='mse',min_samples_leaf=1,min_samples_split=2,n_estimators=200)
rf.fit(X_train,y_train)
rf_predictions=rf.predict(X_test)

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,rf_predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,rf_predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,rf_predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,rf_predictions))
print('r2_score:',r2_score(y_test,rf_predictions))
# Out:
# Mean Absolute Error:  1.490933014354067
# Mean Squared Error:  4.565823145933014
# Root Mean Squared Error:  2.1367786843594763
# Explained Variance Score:  0.5420623637157502
# r2_score: 0.5419822184004263

# %% [markdown]
# THE BEST MODEL AFTER HYPER PARAMETER TUNING IS Random Forest Regressor

# %%
print("FINAL MODEL")
print("-----------------------------------------")
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,rf_predictions))
print('Mean Squared Error: ',metrics.mean_squared_error(y_test,rf_predictions))
print('Root Mean Squared Error: ',np.sqrt(metrics.mean_squared_error(y_test,rf_predictions)))
print('Explained Variance Score: ',metrics.explained_variance_score(y_test,rf_predictions))
print('r2_score:',r2_score(y_test,rf_predictions))
# Out:
# FINAL MODEL
# -----------------------------------------
# Mean Absolute Error:  1.490933014354067
# Mean Squared Error:  4.565823145933014
# Root Mean Squared Error:  2.1367786843594763
# Explained Variance Score:  0.5420623637157502
# r2_score: 0.5419822184004263

# %%
sns.distplot(rf_predictions-y_test)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %%
plt.scatter(rf_predictions,y_test)
plt.plot(y_test,y_test,linewidth=4,color='Red')

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib
joblib.dump(rf,"final model.pkl")
# Out:
# ['final model.pkl']
